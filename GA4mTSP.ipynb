# %% [markdown]
# # Genetic Algorithm for Multiple Traveling Salesman Problem

# %% [markdown]
# ## 1. Baseline

# %% [markdown]
# 1. Run baseline on the `mtsp51` instance

# %%
# !python main.py -d instances/mtsp51.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp51.txt
# 	>> 51 cities in total to be loaded
# > 51 cities loaded from instances/mtsp51.txt
# > Initial distance: 1474.351761
# > Starting running GA.
# 	>> cities = 51, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1368.456147
# % 2 1378.363794
# % 3 1312.693613
# % 4 1303.866101
# % 5 1285.894671
# % 6 1241.413479
# % 7 1242.272361
# % 8 1212.894964
# % 9 1232.607073
# % 10 1191.044600
# % 11 1173.631541
# % 12 1169.459457
# % 13 1164.650865
# % 14 1210.811897
# % 15 1178.911513
# % 16 1152.928731
# % 17 1139.231058
# % 18 1118.352580
# % 19 1122.107685
# % 20 1125.884237
# % 21 1132.402382
# % 22 1125.689426
# % 23 1108.851812
# % 24 1112.747582
# % 25 1063.384525
# % 26 1105.524920
# % 27 1084.469188
# % 28 1087.115954
# % 29 1090.883835
# % 30 1087.749592
# % 31 1112.175074
# % 32 1130.875952
# % 33 1118.080257
# % 34 1160.593096
# % 35 1109.152939
# % 36 1070.898191
# % 37 1063.246457
# % 38 1023.872068
# % 39 1056.552402
# % 40 1018.570442
# % 41 1034.285220
# % 42 1039.240983
# % 43 1041.631296
# % 44 996.450147
# % 45 1002.628038
# % 46 1043.868656
# % 47 1029.907198
# % 48 1033.028819
# % 49 1089.725481
# % 50 1044.091205
# % 51 1034.958958
# % 52 1040.960466
# % 53 1038.809558
# % 54 1073.992276
# % 55 1069.995664
# % 56 1006.351845
# % 57 1026.397830
# % 58 1041.258561
# % 59 1048.393404
# % 60 997.283002
# % 61 1007.865602
# % 62 1007.135845
# % 63 999.419980
# % 64 984.586845
# % 65 1003.332138
# % 66 1023.423413
# % 67 1016.281362
# % 68 988.557317
# % 69 1010.317793
# % 70 996.344379
# % 71 994.929821
# % 72 1038.678821
# % 73 990.998601
# % 74 1002.874103
# % 75 1041.987084
# % 76 1043.627001
# % 77 1041.613931
# % 78 1047.723410
# % 79 1026.224501
# % 80 997.416883
# % 81 1002.304707
# % 82 1000.398179
# % 83 1030.278919
# % 84 1041.839378
# % 85 1019.807086
# % 86 1027.366109
# % 87 993.892580
# % 88 1006.297878
# % 89 1005.099246
# % 90 1047.764015
# % 91 1032.683450
# % 92 1050.026531
# % 93 1047.128282
# % 94 1051.953573
# % 95 1061.159863
# % 96 1060.803687
# % 97 1099.661781
# % 98 1077.806852
# % 99 1101.608401
# % 100 1109.934380
# % 101 1029.802749
# % 102 1083.625231
# % 103 1039.801338
# % 104 1045.702644
# % 105 1077.581359
# % 106 1057.040673
# % 107 1072.270655
# % 108 1039.013706
# % 109 1043.543366
# % 110 1067.573098
# % 111 1080.350290
# % 112 1074.135995
# % 113 1070.088530
# % 114 1014.663970
# % 115 1019.393887
# % 116 1013.471569
# % 117 1046.559732
# % 118 1030.572047
# % 119 1043.109528
# % 120 1074.541049
# % 121 1040.842741
# % 122 951.533872
# % 123 1007.788905
# % 124 1003.038357
# % 125 1020.018834
# % 126 1055.834554
# % 127 1044.066995
# % 128 1051.119404
# % 129 1068.852905
# % 130 1090.067042
# % 131 1075.145918
# % 132 1069.024613
# % 133 1075.645303
# % 134 1123.562964
# % 135 1056.076916
# % 136 1100.861295
# % 137 1109.667417
# % 138 1058.066614
# % 139 1022.639936
# % 140 1043.181356
# % 141 1027.493248
# % 142 1081.686594
# % 143 1028.700575
# % 144 1024.954539
# % 145 1017.510220
# % 146 994.306170
# % 147 1022.330858
# % 148 1044.383823
# % 149 1052.127281
# % 150 1089.311661
# % 151 1008.357590
# % 152 999.344027
# % 153 937.486279
# % 154 996.961078
# % 155 999.072484
# % 156 994.138008
# % 157 967.935109
# % 158 1013.889395
# % 159 995.217773
# % 160 1006.402880
# % 161 1005.327653
# % 162 993.660651
# % 163 1005.928264
# % 164 1004.064914
# % 165 1034.273920
# % 166 967.791246
# % 167 978.307309
# % 168 977.270419
# % 169 991.652246
# % 170 941.366003
# % 171 998.406030
# % 172 918.111364
# % 173 945.556238
# % 174 982.440292
# % 175 923.412016
# % 176 983.009520
# % 177 1006.687593
# % 178 1037.131754
# % 179 992.099630
# % 180 958.195214
# % 181 996.655842
# % 182 956.636018
# % 183 967.034696
# % 184 977.574862
# % 185 984.347696
# % 186 985.957298
# % 187 1026.050850
# % 188 1032.886145
# % 189 1064.201291
# % 190 1016.842034
# % 191 1053.917117
# % 192 1016.188143
# % 193 1046.693574
# % 194 992.163982
# % 195 1005.443622
# % 196 1023.944713
# % 197 1025.523175
# % 198 1057.632308
# % 199 1018.482693
# % 200 1030.383567
# % 201 1047.008912
# % 202 1047.955445
# % 203 1057.375267
# > Finished 203 generations with 1016070 distance calculations. GA Runtime = 16.9269 sec
# > Final distance: 918.111364
# > Final Route:
# Truck 0 [len = 16]: 0 --> 32 --> 43 --> 36 --> 16 --> 46 --> 10 --> 14 --> 44 --> 9 --> 29 --> 4 --> 49 --> 28 --> 2 --> 35
# Truck 1 [len = 13]: 0 --> 42 --> 23 --> 24 --> 13 --> 17 --> 3 --> 40 --> 18 --> 12 --> 41 --> 39 --> 11
# Truck 2 [len = 8]: 0 --> 31 --> 50 --> 33 --> 34 --> 19 --> 25 --> 21
# Truck 3 [len = 11]: 0 --> 26 --> 1 --> 37 --> 8 --> 15 --> 20 --> 22 --> 30 --> 7 --> 27
# Truck 4 [len = 7]: 0 --> 45 --> 38 --> 48 --> 5 --> 6 --> 47
# > Generation - Distance curve saved to fig/20211222_03_52_08.png.

# %% [markdown]
# 2. `mtsp100`

# %%
# !python main.py -d instances/mtsp100.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp100.txt
# 	>> 100 cities in total to be loaded
# > 100 cities loaded from instances/mtsp100.txt
# > Initial distance: 151300.221844
# > Starting running GA.
# 	>> cities = 100, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 143415.233637
# % 2 141297.948850
# % 3 139373.608271
# % 4 137354.663812
# % 5 137611.068547
# % 6 135731.358672
# % 7 133322.078729
# % 8 130487.662361
# % 9 128056.534934
# % 10 126194.393207
# % 11 126749.340944
# % 12 126134.685580
# % 13 122668.982859
# % 14 120941.987371
# % 15 121028.912319
# % 16 118087.911107
# % 17 116002.737892
# % 18 116164.939177
# % 19 116447.767310
# % 20 116327.059062
# % 21 112923.456943
# % 22 112366.421242
# % 23 110882.639913
# % 24 108755.309321
# % 25 109988.589025
# % 26 109804.940488
# % 27 106810.769624
# % 28 107554.764686
# % 29 109699.950404
# % 30 107315.926229
# % 31 104372.417213
# % 32 107200.380853
# % 33 104330.661167
# % 34 104830.129664
# % 35 104880.282355
# % 36 102561.894200
# % 37 99560.111693
# % 38 103559.925876
# % 39 98192.735083
# % 40 100757.953948
# % 41 100209.850042
# % 42 100486.534590
# % 43 100958.156715
# % 44 95127.975721
# % 45 95150.915752
# % 46 97841.693561
# % 47 96167.905771
# % 48 95566.418493
# % 49 97155.236551
# % 50 94392.365879
# % 51 95541.416275
# % 52 94862.767069
# % 53 92278.662663
# % 54 93288.087522
# % 55 94288.252269
# % 56 92013.994787
# % 57 94020.531887
# % 58 89288.562385
# % 59 87951.934506
# % 60 90592.711810
# % 61 92967.397378
# % 62 91953.972776
# % 63 91598.339799
# % 64 92470.594511
# % 65 93092.081190
# % 66 95585.839861
# % 67 95948.131247
# % 68 94003.765843
# % 69 93696.053327
# % 70 95958.651857
# % 71 96584.131608
# % 72 97113.140134
# % 73 94943.627148
# % 74 96485.268967
# % 75 95107.912396
# % 76 94841.215858
# % 77 96550.615377
# % 78 98224.818617
# % 79 98149.941063
# % 80 95912.376969
# % 81 97595.513951
# % 82 94696.063887
# % 83 94648.487098
# % 84 93332.482975
# % 85 93409.049303
# % 86 89716.977785
# % 87 88198.801449
# % 88 90069.312092
# % 89 90304.200809
# % 90 87933.426748
# % 91 89527.839752
# % 92 88450.292975
# % 93 89152.967627
# % 94 88868.910401
# % 95 89021.476986
# % 96 88692.117607
# % 97 90833.097852
# % 98 87714.894444
# % 99 87993.640294
# % 100 88972.812307
# % 101 88834.879834
# % 102 88757.422614
# % 103 87183.382460
# % 104 86436.951607
# % 105 88316.832374
# % 106 89598.174584
# % 107 89337.258568
# % 108 88770.010771
# % 109 91079.188078
# % 110 94021.768193
# % 111 94415.111268
# % 112 94249.865751
# % 113 96771.863143
# % 114 89828.011225
# % 115 90058.691345
# % 116 95448.025140
# % 117 90292.426718
# % 118 90139.754227
# % 119 87141.863371
# % 120 88179.985233
# % 121 85331.580337
# % 122 87984.890673
# % 123 88555.593932
# % 124 89322.700802
# % 125 87930.338227
# % 126 89096.188017
# % 127 90133.555801
# % 128 87722.046809
# % 129 89402.739535
# % 130 87336.680813
# % 131 90369.070829
# % 132 88064.981499
# % 133 89166.728475
# % 134 89155.842099
# % 135 88838.916294
# % 136 85724.063268
# % 137 84665.991288
# % 138 86851.161377
# % 139 85965.381725
# % 140 88180.725562
# % 141 89043.827032
# % 142 88515.836266
# % 143 85809.552172
# % 144 88070.873990
# % 145 88292.927106
# % 146 90950.967158
# % 147 89534.859950
# % 148 89421.864959
# % 149 89589.387621
# % 150 90873.677870
# % 151 90447.566849
# % 152 87964.084511
# % 153 88653.071192
# % 154 88421.847628
# % 155 85604.726701
# % 156 88796.219586
# % 157 88840.988298
# % 158 87923.978826
# % 159 90628.326042
# % 160 87686.033185
# % 161 89716.549744
# % 162 87390.184415
# % 163 85215.756980
# % 164 87424.576784
# % 165 88340.129249
# % 166 87648.093834
# % 167 88014.690214
# % 168 86728.017010
# % 169 88282.566750
# % 170 87179.976619
# % 171 86905.897926
# % 172 85510.210957
# % 173 86235.146605
# % 174 87503.403404
# % 175 87990.586416
# % 176 86539.586693
# % 177 86568.973889
# % 178 87670.902365
# % 179 86029.853720
# % 180 89821.849643
# % 181 88031.390039
# % 182 90986.662010
# % 183 88688.655303
# % 184 89466.747349
# % 185 87484.941787
# % 186 89343.807899
# % 187 90039.647414
# % 188 87325.242889
# % 189 89837.661527
# % 190 89613.822700
# % 191 87181.627639
# % 192 90282.535761
# % 193 92377.403853
# % 194 90905.774318
# % 195 92257.933276
# % 196 91799.379495
# % 197 93610.866920
# % 198 93084.052499
# % 199 95404.254013
# % 200 95873.771098
# % 201 94592.920816
# % 202 90962.352108
# % 203 93034.828301
# % 204 91835.512865
# % 205 91618.931292
# % 206 93408.056257
# % 207 91941.223194
# % 208 90494.403355
# % 209 93704.387593
# % 210 93473.421178
# % 211 92565.499153
# > Finished 211 generations with 1995968 distance calculations. GA Runtime = 41.3217 sec
# > Final distance: 84665.991288
# > Final Route:
# Truck 0 [len = 13]: 0 --> 80 --> 6 --> 82 --> 50 --> 47 --> 18 --> 29 --> 24 --> 55 --> 54 --> 91 --> 9
# Truck 1 [len = 18]: 0 --> 83 --> 78 --> 88 --> 16 --> 89 --> 49 --> 38 --> 67 --> 84 --> 95 --> 42 --> 25 --> 99 --> 1 --> 39 --> 61 --> 23
# Truck 2 [len = 29]: 0 --> 33 --> 63 --> 14 --> 58 --> 8 --> 59 --> 4 --> 86 --> 17 --> 2 --> 11 --> 76 --> 15 --> 5 --> 43 --> 34 --> 36 --> 52 --> 98 --> 81 --> 94 --> 27 --> 20 --> 92 --> 3 --> 7 --> 66 --> 74
# Truck 3 [len = 26]: 0 --> 65 --> 41 --> 22 --> 79 --> 90 --> 68 --> 45 --> 85 --> 72 --> 31 --> 21 --> 57 --> 97 --> 96 --> 48 --> 69 --> 93 --> 30 --> 44 --> 71 --> 60 --> 73 --> 28 --> 35 --> 51
# Truck 4 [len = 18]: 0 --> 70 --> 19 --> 46 --> 32 --> 26 --> 12 --> 75 --> 56 --> 40 --> 87 --> 53 --> 77 --> 13 --> 64 --> 62 --> 10 --> 37
# > Generation - Distance curve saved to fig/20211216_15_11_14.png.

# %% [markdown]
# 3. `mtsp150`

# %%
# !python main.py -d instances/mtsp150.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp150.txt
# 	>> 150 cities in total to be loaded
# > 150 cities loaded from instances/mtsp150.txt
# > Initial distance: 274418.408125
# > Starting running GA.
# 	>> cities = 150, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 271258.978152
# % 2 269764.004968
# % 3 264299.738790
# % 4 262815.993397
# % 5 261570.256862
# % 6 258828.466564
# % 7 252444.845892
# % 8 248005.724312
# % 9 246705.967606
# % 10 238992.348080
# % 11 236149.629381
# % 12 234071.445162
# % 13 231648.118206
# % 14 229493.563394
# % 15 227010.344537
# % 16 225319.928949
# % 17 223522.380479
# % 18 223181.292251
# % 19 219088.610614
# % 20 217985.716506
# % 21 218674.996114
# % 22 215495.415431
# % 23 217334.177544
# % 24 214973.934733
# % 25 214413.307187
# % 26 213803.032970
# % 27 212917.176937
# % 28 213385.242548
# % 29 210067.683165
# % 30 207309.428554
# % 31 205654.058048
# % 32 205456.355887
# % 33 205369.923756
# % 34 207742.975004
# % 35 201751.916017
# % 36 201748.619417
# % 37 200179.705355
# % 38 200258.882443
# % 39 197056.959095
# % 40 192911.826158
# % 41 192402.173490
# % 42 190821.819696
# % 43 191733.596718
# % 44 188507.050039
# % 45 184154.248596
# % 46 182626.685978
# % 47 183641.294539
# % 48 182215.972647
# % 49 181598.860616
# % 50 178434.803683
# % 51 178034.300684
# % 52 175130.190295
# % 53 174345.816145
# % 54 174077.546518
# % 55 175248.182317
# % 56 172203.761186
# % 57 174345.730581
# % 58 171019.047671
# % 59 171133.148049
# % 60 171277.391289
# % 61 171123.606674
# % 62 166767.992200
# % 63 168685.256038
# % 64 169832.735977
# % 65 168654.480058
# % 66 166692.268016
# % 67 167342.990457
# % 68 168905.885640
# % 69 169693.565299
# % 70 168025.485930
# % 71 166587.011504
# % 72 163929.138710
# % 73 164187.404091
# % 74 162713.545610
# % 75 163323.804423
# % 76 158114.216865
# % 77 157754.102563
# % 78 157168.343460
# % 79 154136.426272
# % 80 155101.538935
# % 81 157926.805658
# % 82 157687.904488
# % 83 156129.721024
# % 84 155205.039104
# % 85 154298.074836
# % 86 153596.844925
# % 87 151052.449654
# % 88 151117.098725
# % 89 148480.972242
# % 90 146624.557016
# % 91 147634.757616
# % 92 148366.614406
# % 93 149188.531003
# % 94 149530.787055
# % 95 147902.433742
# % 96 148476.816656
# % 97 149041.751738
# % 98 148498.031461
# % 99 150306.901161
# % 100 150558.482836
# % 101 150648.583961
# % 102 151209.282978
# % 103 151964.947605
# % 104 150666.276366
# % 105 150227.353178
# % 106 151255.266062
# % 107 151702.384976
# % 108 152152.176225
# % 109 149867.722223
# % 110 153250.091697
# % 111 150136.436885
# % 112 151353.088392
# % 113 151967.976159
# % 114 152595.930758
# % 115 152045.421717
# % 116 152568.618099
# % 117 149988.358922
# % 118 147095.886754
# % 119 151196.529078
# % 120 149827.056669
# % 121 153415.769832
# % 122 153203.745080
# % 123 152955.018548
# % 124 153898.570353
# % 125 151499.449089
# % 126 151703.970861
# % 127 150527.593390
# % 128 150862.525693
# % 129 151520.899696
# % 130 151229.741947
# % 131 153940.114875
# % 132 151221.598169
# % 133 150433.049531
# % 134 149073.409239
# % 135 152564.316315
# % 136 153618.867753
# % 137 153239.683570
# % 138 151397.876165
# % 139 151961.106299
# % 140 153832.877388
# % 141 154596.195634
# % 142 153530.122899
# % 143 151713.936050
# % 144 151479.460413
# % 145 154471.023344
# % 146 154010.610377
# % 147 153610.180277
# % 148 152252.558052
# % 149 152398.116468
# % 150 152476.622505
# % 151 153015.861454
# % 152 154367.249139
# % 153 149277.043791
# % 154 151682.722544
# % 155 149549.164433
# % 156 150921.527653
# % 157 151461.336130
# % 158 152331.096019
# % 159 151224.476283
# % 160 148979.700175
# % 161 146827.376773
# % 162 144851.805046
# % 163 145087.126691
# % 164 146711.136327
# % 165 146229.349543
# % 166 145492.336531
# % 167 147765.021471
# % 168 149115.182409
# % 169 148569.009542
# % 170 148711.051990
# % 171 148876.544883
# % 172 152312.605516
# % 173 151615.852134
# % 174 150768.716952
# % 175 150558.893453
# % 176 149733.213707
# % 177 151414.651233
# % 178 152648.450141
# % 179 149142.931704
# % 180 148712.382082
# % 181 147494.980901
# % 182 148543.079781
# % 183 149064.750205
# % 184 144553.937767
# % 185 141197.773569
# % 186 139905.737216
# % 187 140509.405873
# % 188 140770.588857
# % 189 138763.494081
# % 190 139185.569534
# % 191 140112.203331
# % 192 138039.381140
# % 193 137786.006875
# % 194 136752.679298
# % 195 136245.447625
# % 196 137710.976166
# % 197 135553.243523
# % 198 139118.395987
# % 199 137929.235270
# % 200 139911.337814
# % 201 141871.969740
# % 202 141618.598382
# % 203 143931.788311
# % 204 142748.163224
# % 205 144189.555534
# % 206 145457.833835
# % 207 148694.516537
# % 208 145603.601928
# % 209 145253.452754
# % 210 144397.561943
# % 211 142592.762114
# % 212 146071.481922
# % 213 150357.569615
# % 214 147024.575419
# > Finished 214 generations with 2999920 distance calculations. GA Runtime = 77.4841 sec
# > Final distance: 135553.243523
# > Final Route:
# Truck 0 [len = 24]: 0 --> 70 --> 127 --> 49 --> 86 --> 100 --> 66 --> 124 --> 21 --> 129 --> 30 --> 130 --> 138 --> 41 --> 136 --> 5 --> 71 --> 121 --> 132 --> 116 --> 67 --> 139 --> 2 --> 46
# Truck 1 [len = 34]: 0 --> 10 --> 76 --> 6 --> 59 --> 84 --> 53 --> 144 --> 39 --> 43 --> 4 --> 120 --> 26 --> 77 --> 36 --> 105 --> 104 --> 56 --> 47 --> 135 --> 28 --> 61 --> 82 --> 16 --> 111 --> 141 --> 74 --> 118 --> 52 --> 14 --> 50 --> 125 --> 1 --> 63
# Truck 2 [len = 30]: 0 --> 115 --> 40 --> 51 --> 13 --> 149 --> 101 --> 112 --> 88 --> 24 --> 12 --> 137 --> 96 --> 142 --> 65 --> 133 --> 123 --> 69 --> 3 --> 97 --> 103 --> 20 --> 73 --> 113 --> 83 --> 87 --> 25 --> 35 --> 98 --> 15
# Truck 3 [len = 38]: 0 --> 42 --> 119 --> 114 --> 19 --> 108 --> 140 --> 37 --> 93 --> 23 --> 72 --> 143 --> 107 --> 11 --> 33 --> 95 --> 80 --> 102 --> 32 --> 64 --> 94 --> 81 --> 68 --> 78 --> 106 --> 38 --> 146 --> 29 --> 134 --> 92 --> 91 --> 31 --> 85 --> 90 --> 126 --> 147 --> 18 --> 7
# Truck 4 [len = 28]: 0 --> 109 --> 57 --> 131 --> 9 --> 110 --> 48 --> 117 --> 128 --> 89 --> 17 --> 58 --> 44 --> 62 --> 148 --> 122 --> 34 --> 8 --> 22 --> 27 --> 79 --> 60 --> 145 --> 45 --> 99 --> 54 --> 75 --> 55
# > Generation - Distance curve saved to fig/20211216_15_11_57.png.

# %% [markdown]
# 4. `pr76`

# %%
# !python main.py -d instances/pr76.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr76.txt
# 	>> 76 cities in total to be loaded
# > 76 cities loaded from instances/pr76.txt
# > Initial distance: 554141.692477
# > Starting running GA.
# 	>> cities = 76, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 526248.586311
# % 2 513855.121002
# % 3 503485.253096
# % 4 480826.692283
# % 5 471944.138189
# % 6 474209.195787
# % 7 463566.642294
# % 8 467985.636009
# % 9 447334.651507
# % 10 450017.052735
# % 11 444343.761316
# % 12 443012.371623
# % 13 439696.137022
# % 14 443294.256139
# % 15 440522.785323
# % 16 434290.406397
# % 17 439550.028974
# % 18 441924.672155
# % 19 431743.664205
# % 20 429567.822056
# % 21 419251.453939
# % 22 429621.153592
# % 23 417280.872320
# % 24 427602.078461
# % 25 415821.480818
# % 26 400860.661515
# % 27 407563.616217
# % 28 407182.451682
# % 29 402649.419241
# % 30 396750.063763
# % 31 396164.898618
# % 32 394747.381812
# % 33 394045.039329
# % 34 392469.652915
# % 35 400841.279691
# % 36 390634.862225
# % 37 399052.927544
# % 38 399274.296546
# % 39 396325.148081
# % 40 385651.962827
# % 41 395401.668788
# % 42 382954.728813
# % 43 389096.734522
# % 44 380945.000542
# % 45 386659.953268
# % 46 393173.999999
# % 47 383150.270204
# % 48 377570.378034
# % 49 381161.977083
# % 50 372137.087335
# % 51 382116.371918
# % 52 382770.619360
# % 53 373743.368294
# % 54 379196.023227
# % 55 385374.105598
# % 56 382192.101997
# % 57 378683.322182
# % 58 373222.723705
# % 59 364555.568785
# % 60 364000.760044
# % 61 361172.386348
# % 62 360180.973784
# % 63 354106.737971
# % 64 361513.924928
# % 65 355466.813872
# % 66 355625.977544
# % 67 367125.901898
# % 68 361129.561903
# % 69 358939.494794
# % 70 369108.515833
# % 71 365662.386024
# % 72 362135.732559
# % 73 366273.931953
# % 74 362435.439527
# % 75 364055.283053
# % 76 367728.630093
# % 77 354139.546703
# % 78 368671.098973
# % 79 363534.530950
# % 80 354655.602219
# % 81 354629.039087
# % 82 348843.188671
# % 83 354650.428606
# % 84 369243.967994
# % 85 360736.358861
# % 86 375130.712790
# % 87 376424.937576
# % 88 366624.469086
# % 89 358953.962920
# % 90 372507.372343
# % 91 373047.931491
# % 92 374501.751467
# % 93 374734.409006
# % 94 367661.049159
# % 95 361939.093599
# % 96 369244.518644
# % 97 367490.004358
# % 98 367830.529435
# % 99 367941.102036
# % 100 370127.172820
# % 101 358509.594864
# % 102 364257.094487
# % 103 369039.225995
# % 104 354716.860630
# % 105 356689.059305
# % 106 366410.373700
# % 107 374238.078726
# % 108 362706.264546
# % 109 376127.525692
# % 110 374968.886381
# % 111 367724.217283
# % 112 380947.805062
# % 113 374786.164460
# % 114 376966.528300
# % 115 369976.673475
# % 116 375053.480993
# % 117 369133.754605
# % 118 366229.723150
# % 119 363177.557365
# % 120 353480.214892
# % 121 367169.184339
# % 122 362184.561477
# % 123 364319.711210
# % 124 358975.616955
# % 125 368624.991660
# % 126 377511.020170
# % 127 368217.694148
# % 128 359619.303797
# % 129 376014.305437
# % 130 364465.895618
# % 131 367992.991583
# % 132 367164.070063
# % 133 377901.939977
# % 134 362828.472569
# % 135 373980.960850
# % 136 369522.287530
# % 137 379026.617038
# % 138 370906.990725
# % 139 361913.092349
# % 140 377873.821067
# % 141 373554.991054
# % 142 373448.211527
# % 143 343552.763986
# % 144 343944.415123
# % 145 349572.535922
# % 146 345837.991439
# % 147 339763.990998
# % 148 330003.339131
# % 149 341670.403673
# % 150 345327.968644
# % 151 357397.928393
# % 152 349234.659909
# % 153 360818.526957
# % 154 348395.529867
# % 155 344959.535288
# % 156 357056.701369
# % 157 364467.247674
# % 158 361614.781344
# % 159 370366.324998
# % 160 368350.579192
# % 161 361303.683265
# % 162 360094.207723
# % 163 353642.222090
# % 164 361123.609825
# % 165 350894.071917
# % 166 353294.679713
# % 167 357094.535784
# % 168 348906.789882
# % 169 356735.702688
# % 170 349089.386770
# % 171 343539.115747
# % 172 349256.139641
# % 173 359115.616441
# % 174 351120.297188
# % 175 347374.498579
# % 176 351754.606306
# % 177 346815.796431
# % 178 357120.799885
# % 179 348526.973223
# % 180 349394.560127
# % 181 351480.667518
# % 182 359014.685830
# % 183 361461.242224
# % 184 342595.721406
# % 185 343978.691705
# % 186 356188.692466
# % 187 357109.453433
# % 188 354713.143733
# % 189 356892.048945
# % 190 358643.149504
# % 191 350983.347442
# % 192 372726.506353
# % 193 375414.078121
# % 194 373544.864136
# % 195 378082.614851
# % 196 370244.537976
# % 197 383497.582288
# % 198 378015.061398
# % 199 368361.002843
# % 200 374983.471640
# % 201 366964.659773
# % 202 372685.013853
# % 203 374517.972570
# % 204 370449.165838
# % 205 371222.237198
# % 206 374752.411071
# % 207 370845.136844
# % 208 383195.967316
# > Finished 208 generations with 1514400 distance calculations. GA Runtime = 26.8665 sec
# > Final distance: 330003.339131
# > Final Route:
# Truck 0 [len = 13]: 0 --> 67 --> 68 --> 66 --> 69 --> 63 --> 60 --> 58 --> 31 --> 34 --> 40 --> 61 --> 48
# Truck 1 [len = 16]: 0 --> 10 --> 5 --> 3 --> 8 --> 27 --> 30 --> 18 --> 19 --> 73 --> 16 --> 35 --> 36 --> 38 --> 15 --> 9
# Truck 2 [len = 14]: 0 --> 22 --> 24 --> 26 --> 49 --> 65 --> 54 --> 56 --> 71 --> 72 --> 44 --> 20 --> 74 --> 75
# Truck 3 [len = 18]: 0 --> 1 --> 25 --> 32 --> 37 --> 17 --> 11 --> 14 --> 33 --> 39 --> 53 --> 55 --> 51 --> 64 --> 29 --> 2 --> 12 --> 13
# Truck 4 [len = 19]: 0 --> 6 --> 59 --> 23 --> 47 --> 57 --> 50 --> 62 --> 70 --> 52 --> 28 --> 42 --> 46 --> 43 --> 7 --> 4 --> 41 --> 45 --> 21
# > Generation - Distance curve saved to fig/20211216_15_24_20.png.

# %% [markdown]
# 5. `pr152`

# %%
# !python main.py -d instances/pr152.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr152.txt
# 	>> 152 cities in total to be loaded
# > 152 cities loaded from instances/pr152.txt
# > Initial distance: 1019735.549681
# > Starting running GA.
# 	>> cities = 152, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1006334.198854
# % 2 984184.028238
# % 3 973749.069548
# % 4 938209.740592
# % 5 938344.196521
# % 6 926869.712875
# % 7 925807.113168
# % 8 904704.721885
# % 9 895406.175837
# % 10 889039.902779
# % 11 871722.022726
# % 12 870988.356411
# % 13 875164.701121
# % 14 868209.459536
# % 15 856988.296470
# % 16 863977.362977
# % 17 846380.935639
# % 18 832906.368990
# % 19 827514.474401
# % 20 817810.668586
# % 21 808427.603730
# % 22 794325.594463
# % 23 780481.218427
# % 24 778146.129834
# % 25 759018.750916
# % 26 746371.257214
# % 27 754322.653564
# % 28 744018.353393
# % 29 729986.373404
# % 30 725774.860484
# % 31 719724.259632
# % 32 714034.707687
# % 33 719897.979020
# % 34 709270.277590
# % 35 717214.836544
# % 36 718579.041814
# % 37 715355.618233
# % 38 707491.549619
# % 39 704221.851088
# % 40 692864.407362
# % 41 685725.413645
# % 42 687406.876638
# % 43 688413.081672
# % 44 686418.484888
# % 45 693967.652130
# % 46 667373.967270
# % 47 672479.699367
# % 48 673925.448713
# % 49 661514.617125
# % 50 658208.537660
# % 51 642021.422796
# % 52 634098.738061
# % 53 639824.016505
# % 54 621363.150520
# % 55 625868.166972
# % 56 628660.649347
# % 57 614255.750215
# % 58 623433.662019
# % 59 616703.780655
# % 60 619325.549438
# % 61 620172.008199
# % 62 621454.488381
# % 63 614553.307093
# % 64 620919.718396
# % 65 601648.323584
# % 66 607038.647631
# % 67 583403.118125
# % 68 591549.764251
# % 69 592893.927028
# % 70 591800.112693
# % 71 568099.803705
# % 72 571008.256215
# % 73 560477.807785
# % 74 564916.027166
# % 75 564175.799549
# % 76 575978.009461
# % 77 564601.097015
# % 78 568705.635780
# % 79 566047.093967
# % 80 565300.214201
# % 81 574409.256054
# % 82 591781.599617
# % 83 567118.949309
# % 84 583561.132674
# % 85 574718.697710
# % 86 591243.071359
# % 87 567381.185965
# % 88 574585.112391
# % 89 577032.783492
# % 90 579909.902250
# % 91 574180.070404
# % 92 583479.614028
# % 93 572617.403833
# % 94 581468.552816
# % 95 580573.233654
# % 96 591196.146734
# % 97 575053.272705
# % 98 580092.155734
# % 99 598602.711576
# % 100 590991.303766
# % 101 586389.272217
# % 102 594083.648002
# % 103 587227.896295
# % 104 591528.406686
# % 105 596389.592920
# % 106 605388.427076
# % 107 601291.759330
# % 108 601586.645914
# % 109 604064.721244
# % 110 600387.107001
# % 111 602610.680939
# % 112 595064.702824
# % 113 603672.210273
# % 114 602736.868687
# % 115 611854.875965
# % 116 603872.334110
# % 117 594655.810291
# % 118 584467.803847
# % 119 585720.614545
# % 120 584688.389863
# % 121 605949.053413
# % 122 605123.073455
# % 123 611196.221251
# % 124 604000.293506
# % 125 602426.300170
# % 126 591595.678100
# % 127 597675.923459
# % 128 609586.285538
# % 129 615402.878301
# % 130 607424.701434
# % 131 607703.545544
# % 132 622735.379057
# % 133 610765.134529
# % 134 608146.742857
# % 135 597847.904533
# % 136 595940.375409
# % 137 581546.399832
# % 138 572379.025005
# % 139 588447.226718
# % 140 590820.761059
# % 141 575682.813150
# % 142 585273.565133
# % 143 573857.533877
# % 144 573645.535831
# % 145 587101.808577
# % 146 581291.416511
# % 147 572230.296091
# % 148 590998.680415
# % 149 588542.175756
# % 150 597549.820886
# % 151 597901.859739
# % 152 601058.175143
# % 153 588711.524467
# % 154 589057.213975
# % 155 578299.937533
# % 156 571786.751151
# % 157 575481.387023
# % 158 556342.422597
# % 159 561835.980148
# % 160 562090.359967
# % 161 574622.092281
# % 162 565140.335968
# % 163 558441.283569
# % 164 569569.302938
# % 165 561645.703994
# % 166 567993.935399
# % 167 579544.376881
# % 168 573141.374417
# % 169 561290.980151
# % 170 558999.609980
# % 171 567076.304638
# % 172 571235.320177
# % 173 560719.258467
# % 174 555424.987418
# % 175 571061.795119
# % 176 563609.378775
# % 177 560178.786948
# % 178 575257.803499
# % 179 583171.935821
# % 180 574283.760605
# % 181 567514.736218
# % 182 565787.688293
# % 183 556580.492957
# % 184 564334.821806
# % 185 544131.575366
# % 186 537061.250621
# % 187 544642.594202
# % 188 541549.613066
# % 189 536604.706799
# % 190 541964.581797
# % 191 533063.482993
# % 192 528721.348445
# % 193 548992.591320
# % 194 556623.066230
# % 195 557193.807932
# % 196 567797.817021
# % 197 556739.906215
# % 198 560286.426223
# % 199 569094.118393
# % 200 565307.745711
# % 201 574969.067204
# % 202 582246.527341
# % 203 588349.314386
# % 204 570733.287770
# % 205 561633.147643
# % 206 571848.243570
# % 207 569160.596943
# % 208 574182.231774
# % 209 565572.188203
# % 210 561210.721612
# % 211 559586.746029
# % 212 569109.968410
# % 213 562015.109481
# % 214 570864.059577
# > Finished 214 generations with 3038568 distance calculations. GA Runtime = 80.2549 sec
# > Final distance: 528721.348445
# > Final Route:
# Truck 0 [len = 27]: 0 --> 66 --> 102 --> 14 --> 26 --> 81 --> 65 --> 98 --> 75 --> 76 --> 64 --> 111 --> 126 --> 131 --> 147 --> 120 --> 143 --> 119 --> 99 --> 46 --> 80 --> 112 --> 62 --> 56 --> 67 --> 32 --> 7
# Truck 1 [len = 25]: 0 --> 89 --> 104 --> 127 --> 124 --> 123 --> 49 --> 82 --> 149 --> 135 --> 133 --> 144 --> 134 --> 129 --> 130 --> 140 --> 142 --> 138 --> 87 --> 100 --> 42 --> 113 --> 31 --> 115 --> 72
# Truck 2 [len = 32]: 0 --> 36 --> 57 --> 109 --> 137 --> 116 --> 136 --> 79 --> 114 --> 150 --> 92 --> 91 --> 51 --> 122 --> 77 --> 110 --> 59 --> 40 --> 108 --> 107 --> 52 --> 68 --> 139 --> 145 --> 118 --> 132 --> 117 --> 38 --> 3 --> 4 --> 1 --> 9
# Truck 3 [len = 31]: 0 --> 30 --> 23 --> 21 --> 39 --> 20 --> 18 --> 6 --> 28 --> 13 --> 41 --> 60 --> 88 --> 74 --> 47 --> 50 --> 90 --> 94 --> 95 --> 45 --> 141 --> 121 --> 58 --> 105 --> 83 --> 54 --> 148 --> 151 --> 55 --> 101 --> 34
# Truck 4 [len = 41]: 0 --> 35 --> 19 --> 63 --> 44 --> 86 --> 103 --> 106 --> 71 --> 53 --> 93 --> 73 --> 78 --> 97 --> 146 --> 128 --> 125 --> 69 --> 15 --> 33 --> 12 --> 43 --> 70 --> 48 --> 96 --> 11 --> 10 --> 16 --> 61 --> 84 --> 85 --> 27 --> 29 --> 2 --> 37 --> 24 --> 22 --> 5 --> 25 --> 8 --> 17
# > Generation - Distance curve saved to fig/20211216_15_22_15.png.

# %% [markdown]
# 6. `pr226`

# %%
# !python main.py -d instances/pr226.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr226.txt
# 	>> 226 cities in total to be loaded
# > 226 cities loaded from instances/pr226.txt
# > Initial distance: 1625125.955967
# > Starting running GA.
# 	>> cities = 226, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1597822.585047
# % 2 1588221.987287
# % 3 1562156.239034
# % 4 1550646.773884
# % 5 1538167.426259
# % 6 1531491.759085
# % 7 1523400.369805
# % 8 1516434.521481
# % 9 1504741.970698
# % 10 1495765.129080
# % 11 1486342.044395
# % 12 1466672.466710
# % 13 1477539.409750
# % 14 1471052.539700
# % 15 1469625.568608
# % 16 1449116.748960
# % 17 1431644.408822
# % 18 1428359.861822
# % 19 1432887.472473
# % 20 1410358.842647
# % 21 1413272.557678
# % 22 1393282.708172
# % 23 1398035.537925
# % 24 1382019.355018
# % 25 1377972.432707
# % 26 1379946.737471
# % 27 1364270.511382
# % 28 1363204.372039
# % 29 1361712.067031
# % 30 1337625.423621
# % 31 1339830.936378
# % 32 1331832.936249
# % 33 1332345.260801
# % 34 1322453.338380
# % 35 1310506.871737
# % 36 1304963.964700
# % 37 1292840.684241
# % 38 1282815.215578
# % 39 1279454.325904
# % 40 1283234.243591
# % 41 1281867.087985
# % 42 1261907.776390
# % 43 1263255.314833
# % 44 1261405.108420
# % 45 1235288.770679
# % 46 1258118.698319
# % 47 1249728.440300
# % 48 1230469.429604
# % 49 1219911.721092
# % 50 1213208.670714
# % 51 1213350.563010
# % 52 1202916.510154
# % 53 1196896.625281
# % 54 1206735.649517
# % 55 1191819.549742
# % 56 1190830.686103
# % 57 1187571.307594
# % 58 1190209.486458
# % 59 1187809.233585
# % 60 1182469.690276
# % 61 1176036.419897
# % 62 1183759.942646
# % 63 1181579.095866
# % 64 1176387.320834
# % 65 1165427.755236
# % 66 1163317.124978
# % 67 1160003.744359
# % 68 1158583.961775
# % 69 1148905.604620
# % 70 1144894.955681
# % 71 1118084.733832
# % 72 1135462.368563
# % 73 1112656.160225
# % 74 1124832.898438
# % 75 1111426.428541
# % 76 1102823.757757
# % 77 1084818.601711
# % 78 1071156.302250
# % 79 1072723.320219
# % 80 1045908.384871
# % 81 1044226.756109
# % 82 1045183.771229
# % 83 1043828.381615
# % 84 1046391.628959
# % 85 1044560.154364
# % 86 1051989.524410
# % 87 1044050.771569
# % 88 1041038.751109
# % 89 1024811.702483
# % 90 1032112.685484
# % 91 1006521.830577
# % 92 1018531.441607
# % 93 1006546.036000
# % 94 1005148.286011
# % 95 1006380.402994
# % 96 1024457.724136
# % 97 1020421.455979
# % 98 1013276.749220
# % 99 1019232.291124
# % 100 1021992.215961
# % 101 1018955.560951
# % 102 1014420.164495
# % 103 1005244.050088
# % 104 996844.657396
# % 105 979240.575763
# % 106 991743.105535
# % 107 998260.290069
# % 108 994833.967018
# % 109 993460.671853
# % 110 999881.391598
# % 111 997275.310048
# % 112 984412.093748
# % 113 982274.770528
# % 114 973670.565171
# % 115 971163.289538
# % 116 979240.246751
# % 117 964466.263773
# % 118 952126.898150
# % 119 967815.206176
# % 120 971648.604301
# % 121 973757.805167
# % 122 962104.306217
# % 123 972594.867846
# % 124 973203.885725
# % 125 973336.514716
# % 126 970831.168319
# % 127 976572.179481
# % 128 964761.848663
# % 129 977356.676803
# % 130 963003.792808
# % 131 955684.107971
# % 132 965135.569453
# % 133 959684.063481
# % 134 971113.187000
# % 135 965738.322119
# % 136 968737.236575
# % 137 960988.537484
# % 138 969195.816922
# % 139 968395.363967
# % 140 962291.794547
# % 141 947208.141574
# % 142 965110.080966
# % 143 956183.104768
# % 144 952865.963262
# % 145 949344.672815
# % 146 944295.370565
# % 147 952734.837773
# % 148 943743.217559
# % 149 943073.007883
# % 150 932523.342187
# % 151 930517.117634
# % 152 923941.275744
# % 153 917503.253310
# % 154 927348.861336
# % 155 922560.107178
# % 156 939971.544086
# % 157 931755.110881
# % 158 916101.311202
# % 159 925693.971679
# % 160 931370.152633
# % 161 930898.241589
# % 162 945388.300073
# % 163 923002.855875
# % 164 920512.864187
# % 165 916986.831480
# % 166 932218.466923
# % 167 930565.929812
# % 168 930527.533890
# % 169 927183.829171
# % 170 940998.737853
# % 171 950076.737467
# % 172 949864.926415
# % 173 949354.250939
# % 174 954647.275397
# % 175 948425.826092
# % 176 938994.331413
# % 177 936786.672995
# % 178 947800.182222
# % 179 928254.172533
# % 180 926480.845652
# % 181 898588.957240
# % 182 921536.796932
# % 183 908000.489412
# % 184 916827.115619
# % 185 923857.041374
# % 186 895518.098828
# % 187 897441.810585
# % 188 905659.086118
# % 189 922290.064424
# % 190 925763.350692
# % 191 922315.434209
# % 192 919011.825721
# % 193 925683.050713
# % 194 929670.555732
# % 195 936668.293310
# % 196 920596.186871
# % 197 898746.457378
# % 198 915017.231818
# % 199 909463.995567
# % 200 914177.367149
# % 201 899779.235892
# % 202 896073.136051
# % 203 905611.847912
# % 204 905453.534656
# % 205 905126.322740
# % 206 907526.198718
# % 207 898534.865916
# % 208 904244.738689
# % 209 902356.221118
# % 210 914947.486147
# % 211 913095.740973
# % 212 899242.620114
# % 213 886973.880981
# % 214 904695.925059
# % 215 912590.925133
# > Finished 215 generations with 4501330 distance calculations. GA Runtime = 157.0068 sec
# > Final distance: 886973.880981
# > Final Route:
# Truck 0 [len = 45]: 0 --> 61 --> 58 --> 182 --> 170 --> 91 --> 101 --> 99 --> 86 --> 33 --> 142 --> 186 --> 156 --> 160 --> 159 --> 158 --> 189 --> 152 --> 224 --> 112 --> 103 --> 113 --> 209 --> 197 --> 110 --> 115 --> 24 --> 200 --> 98 --> 147 --> 12 --> 177 --> 183 --> 167 --> 155 --> 161 --> 171 --> 173 --> 143 --> 93 --> 145 --> 211 --> 196 --> 212 --> 213
# Truck 1 [len = 72]: 0 --> 81 --> 78 --> 82 --> 52 --> 55 --> 26 --> 15 --> 66 --> 73 --> 5 --> 16 --> 67 --> 56 --> 57 --> 100 --> 83 --> 135 --> 154 --> 41 --> 31 --> 35 --> 89 --> 169 --> 151 --> 218 --> 131 --> 178 --> 176 --> 174 --> 153 --> 150 --> 50 --> 10 --> 6 --> 76 --> 106 --> 125 --> 120 --> 13 --> 3 --> 199 --> 215 --> 216 --> 185 --> 206 --> 191 --> 124 --> 128 --> 123 --> 79 --> 72 --> 60 --> 48 --> 63 --> 36 --> 19 --> 162 --> 168 --> 34 --> 28 --> 45 --> 122 --> 108 --> 18 --> 47 --> 25 --> 39 --> 140 --> 172 --> 163 --> 96
# Truck 2 [len = 59]: 0 --> 129 --> 130 --> 59 --> 32 --> 37 --> 51 --> 175 --> 180 --> 195 --> 94 --> 136 --> 88 --> 144 --> 149 --> 111 --> 116 --> 188 --> 190 --> 179 --> 87 --> 95 --> 27 --> 127 --> 148 --> 92 --> 104 --> 208 --> 164 --> 137 --> 90 --> 114 --> 107 --> 105 --> 4 --> 68 --> 181 --> 157 --> 138 --> 146 --> 165 --> 198 --> 207 --> 205 --> 214 --> 117 --> 23 --> 44 --> 30 --> 38 --> 40 --> 46 --> 49 --> 21 --> 43 --> 22 --> 29 --> 42 --> 14
# Truck 3 [len = 34]: 0 --> 118 --> 97 --> 139 --> 20 --> 70 --> 75 --> 9 --> 2 --> 1 --> 11 --> 8 --> 80 --> 84 --> 126 --> 119 --> 225 --> 219 --> 222 --> 223 --> 166 --> 141 --> 204 --> 194 --> 193 --> 210 --> 201 --> 132 --> 62 --> 85 --> 77 --> 54 --> 53 --> 69
# Truck 4 [len = 20]: 0 --> 71 --> 192 --> 202 --> 102 --> 64 --> 17 --> 74 --> 7 --> 121 --> 220 --> 65 --> 109 --> 133 --> 134 --> 221 --> 217 --> 184 --> 187 --> 203
# > Generation - Distance curve saved to fig/20211216_15_25_39.png.

# %% [markdown]
# ## 2. JingranGA Algorithm (to compare with baseline)

# %% [markdown]
# As an example, run JingranGA on the `pr226` instance

# %%
# !python main.py -d instances/pr226.txt -ga JingranGA
# Out:
# --> Running ID = 1
# dataset loaded. the path of dataset instances/pr226.txtnum_of_cal_pairs should not larger than 4520000population initfinished, time 17.17039942741394 secondsgeneration 1092, num_of_cal_pairs 4519730, best distance 549477.5967092719
# best route: [[14, 140, 142, 173, 171, 155, 154, 156, 162, 175, 178, 129, 130, 122, 215, 207, 199, 198, 202, 75, 82, 81, 73, 74, 27, 23, 29, 37, 26, 51, 53, 42, 163, 164, 172, 185, 176, 144, 146, 147, 141, 170, 181, 121, 128, 126, 220, 224, 1], [17, 88, 92, 99, 94, 105, 110, 104, 115, 112, 143, 139, 153, 150, 152, 197, 209, 123, 127, 214, 201, 205, 216, 210, 206, 180, 161, 157, 159, 166, 149, 93, 101, 148, 138, 89, 98, 54, 57, 58, 95, 134, 219, 217, 203, 200, 211, 212, 59, 35, 28, 33, 25, 18, 15, 13, 8], [7, 12, 114, 103, 102, 117, 119, 125, 39, 41, 46, 183, 188, 186, 168, 91, 100, 90, 97, 16, 5, 3, 10, 64, 179, 187, 136, 111, 107, 106, 118, 221, 223, 124, 108], [68, 63, 61, 60, 55, 62, 109, 113, 116, 120, 204, 208, 213, 76, 83, 78, 56, 21, 22, 34, 135, 133, 132, 194, 196, 189, 137, 145, 45, 43, 44, 24, 9, 2], [19, 38, 32, 20, 11, 80, 77, 79, 225, 222, 218, 190, 191, 193, 195, 66, 67, 69, 71, 182, 184, 177, 174, 165, 167, 169, 160, 158, 151, 40, 31, 30, 87, 86, 96, 192, 131, 85, 84, 72, 70, 65, 49, 47, 36, 48, 52, 50, 4, 6]]

# %% [markdown]
# For more details, refer to `JingranGA.ipynb`. The log files of JingranGA are really huge, thus we exclude them here.

# %% [markdown]
# ## 3. Statistical Comparison

# %% [markdown]
# 1. As an example, run baseline multiple indenpendent times on the `mtsp51` instance

# %%
# !python runMultiple.py -d instances/mtsp51.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# Out:
# >>> Total independent runs = 30 <<<
# ------------------------------------------------------------------------------------------------------
# Round 1
# ------------------------------------------------------------------------------------------------------
# Round 2
# ------------------------------------------------------------------------------------------------------
# Round 3
# ------------------------------------------------------------------------------------------------------
# Round 4
# ------------------------------------------------------------------------------------------------------
# Round 5
# ------------------------------------------------------------------------------------------------------
# Round 6
# ------------------------------------------------------------------------------------------------------
# Round 7
# ------------------------------------------------------------------------------------------------------
# Round 8
# ------------------------------------------------------------------------------------------------------
# Round 9
# ------------------------------------------------------------------------------------------------------
# Round 10
# ------------------------------------------------------------------------------------------------------
# Round 11
# ------------------------------------------------------------------------------------------------------
# Round 12
# ------------------------------------------------------------------------------------------------------
# Round 13
# ------------------------------------------------------------------------------------------------------
# Round 14
# ------------------------------------------------------------------------------------------------------
# Round 15
# ------------------------------------------------------------------------------------------------------
# Round 16
# ------------------------------------------------------------------------------------------------------
# Round 17
# ------------------------------------------------------------------------------------------------------
# Round 18
# ------------------------------------------------------------------------------------------------------
# Round 19
# ------------------------------------------------------------------------------------------------------
# Round 20
# ------------------------------------------------------------------------------------------------------
# Round 21
# ------------------------------------------------------------------------------------------------------
# Round 22
# ------------------------------------------------------------------------------------------------------
# Round 23
# ------------------------------------------------------------------------------------------------------
# Round 24
# ------------------------------------------------------------------------------------------------------
# Round 25
# ------------------------------------------------------------------------------------------------------
# Round 26
# ------------------------------------------------------------------------------------------------------
# Round 27
# ------------------------------------------------------------------------------------------------------
# Round 28
# ------------------------------------------------------------------------------------------------------
# Round 29
# ------------------------------------------------------------------------------------------------------
# Round 30
# ------------------------------------------------------------------------------------------------------
# >>> 30 runs all finished <<<

# %%
# Run others
# !python runMultiple.py -d instances/mtsp100.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/mtsp150.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/pr76.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/pr152.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/pr226.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %% [markdown]
# 2. Extract result distances and run time from a log folder

# %%
from util import extractResListFromLogDir

logDir = 'res/baseline/log/mtsp51_baseline_30_5_1000_100_10_20211216_16_12_09'
resListBaseline = extractResListFromLogDir(log_dir=logDir, label='distance')
timeListBaseline = extractResListFromLogDir(log_dir=logDir, label='runtime')

print(resListBaseline)
print(timeListBaseline)
# Out:
# [935.259838, 931.553625, 936.604977, 916.21368, 911.51114, 921.76074, 913.963646, 908.636433, 922.938775, 946.991411, 917.352276, 898.459824, 883.544144, 908.959496, 913.476104, 937.03381, 951.133978, 879.216739, 914.875664, 933.946606, 909.424986, 927.623173, 912.488888, 917.45265, 898.19543, 932.266037, 934.032096, 911.03959, 913.493121, 911.405061]
# [17.5474, 17.1401, 17.7111, 18.1373, 18.3399, 17.6038, 17.7031, 17.6792, 17.7911, 17.345, 18.2713, 17.4, 17.8005, 17.8227, 17.3408, 17.7979, 17.4147, 17.2162, 16.9218, 17.7955, 17.8355, 18.755, 17.6441, 17.815, 17.323, 17.6461, 17.6303, 17.6992, 18.3043, 18.1833]

# %%
# resListMyAlgo = None

# %% [markdown]
# 3. Perform Wilcoxon rank sum test using `scipy.stats.ranksums` or `scipy.stats.mannwhitneyu` (Testing of difference passes when `p-value` is below 0.05)

# %%
from scipy.stats import ranksums, mannwhitneyu

# print(ranksums(resListBaseline, resListMyAlgo))
# print(mannwhitneyu(resListBaseline, resListMyAlgo))
