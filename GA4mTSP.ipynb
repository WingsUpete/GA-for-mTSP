# %% [markdown]
# # Genetic Algorithm for Multiple Traveling Salesman Problem

# %% [markdown]
# ## Baseline

# %% [markdown]
# 1. Run baseline on the `mtsp51` instance

# %%
# !python main.py -d instances/mtsp51.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp51.txt
# 	>> 51 cities in total to be loaded
# > 51 cities loaded from instances/mtsp51.txt
# > Initial distance: 1521.082887
# > Starting running GA.
# 	>> cities = 51, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1451.350047
# % 2 1388.350427
# % 3 1412.765884
# % 4 1349.557312
# % 5 1325.082669
# % 6 1326.746011
# % 7 1316.406563
# % 8 1308.374864
# % 9 1283.669436
# % 10 1271.280361
# % 11 1287.033294
# % 12 1282.966953
# % 13 1272.562129
# % 14 1282.915264
# % 15 1271.437048
# % 16 1291.302217
# % 17 1231.662903
# % 18 1216.676691
# % 19 1208.280561
# % 20 1166.643655
# % 21 1158.040103
# % 22 1166.030063
# % 23 1189.969840
# % 24 1154.835447
# % 25 1159.895644
# % 26 1132.529268
# % 27 1119.774552
# % 28 1132.623487
# % 29 1165.721156
# % 30 1080.944181
# % 31 1096.719813
# % 32 1116.688974
# % 33 1095.410500
# % 34 1100.327673
# % 35 1119.066651
# % 36 1115.627354
# % 37 1108.958185
# % 38 1145.027786
# % 39 1098.972416
# % 40 1097.361363
# % 41 1067.513046
# % 42 1055.337321
# % 43 1090.025583
# % 44 1047.644906
# % 45 1076.889063
# % 46 1056.445267
# % 47 1038.262354
# % 48 1065.306575
# % 49 1086.167626
# % 50 1092.647341
# % 51 1068.492039
# % 52 1079.660156
# % 53 1037.634181
# % 54 1043.203020
# % 55 1073.935814
# % 56 1074.796617
# % 57 1022.712516
# % 58 1044.517465
# % 59 1037.505882
# % 60 1017.292608
# % 61 1015.054097
# % 62 1015.014858
# % 63 1032.569742
# % 64 1097.220843
# % 65 1047.196077
# % 66 1038.028159
# % 67 1018.137958
# % 68 1044.429371
# % 69 1013.247782
# % 70 1042.314782
# % 71 1051.701848
# % 72 1070.104268
# % 73 1058.184159
# % 74 1069.915302
# % 75 1066.268036
# % 76 1098.139370
# % 77 1050.940831
# % 78 1054.493928
# % 79 1047.572879
# % 80 1048.378412
# % 81 1044.036634
# % 82 1073.445767
# % 83 1038.349233
# % 84 1021.541920
# % 85 1064.237246
# % 86 1023.872246
# % 87 1034.932696
# % 88 1030.864663
# % 89 1055.409170
# % 90 1036.322799
# % 91 1068.415380
# % 92 1053.855633
# % 93 1057.492857
# % 94 1029.362733
# % 95 1024.887005
# % 96 1013.950048
# % 97 1005.391276
# % 98 1028.937644
# % 99 1057.763255
# % 100 1012.136720
# % 101 1012.953388
# % 102 1059.027736
# % 103 1047.582885
# % 104 1015.185989
# % 105 1009.777762
# % 106 1012.061075
# % 107 1010.363317
# % 108 1030.331988
# % 109 1002.620405
# % 110 1010.124299
# % 111 989.924245
# % 112 1012.878367
# % 113 994.221713
# % 114 999.257008
# % 115 956.734351
# % 116 968.276700
# % 117 1022.557921
# % 118 1019.171389
# % 119 1023.997454
# % 120 1002.080897
# % 121 1045.967500
# % 122 1016.837882
# % 123 1044.341709
# % 124 1023.835667
# % 125 1026.723738
# % 126 1065.191540
# % 127 1055.066877
# % 128 1069.249102
# % 129 1106.578186
# % 130 1086.271697
# % 131 1075.223930
# % 132 1056.613121
# % 133 1040.516064
# % 134 1053.036701
# % 135 1031.140389
# % 136 1053.824921
# % 137 1014.278555
# % 138 963.672406
# % 139 1014.025534
# % 140 966.227486
# % 141 995.246879
# % 142 983.824264
# % 143 969.031216
# % 144 1010.574341
# % 145 991.244632
# % 146 1004.698572
# % 147 1002.153685
# % 148 1008.670345
# % 149 1002.577219
# % 150 978.882019
# % 151 964.846106
# % 152 984.404509
# % 153 1022.356783
# % 154 956.307881
# % 155 981.528356
# % 156 971.473903
# % 157 1013.336264
# % 158 1044.675081
# % 159 987.601265
# % 160 996.554550
# % 161 1011.238814
# % 162 1013.094612
# % 163 1021.168965
# % 164 1026.404685
# % 165 1017.786604
# % 166 1038.331454
# % 167 1028.414487
# % 168 1052.202766
# % 169 1063.935304
# % 170 1037.458212
# % 171 1018.804817
# % 172 1097.965084
# % 173 1060.850778
# % 174 1091.993734
# % 175 1084.850078
# % 176 1065.202883
# % 177 1057.712576
# % 178 1036.058669
# % 179 992.917095
# % 180 1022.231704
# % 181 1051.467033
# % 182 1067.050741
# % 183 1081.435541
# % 184 1049.719237
# % 185 1029.980854
# % 186 1000.435170
# % 187 967.842996
# % 188 972.276839
# % 189 1006.737327
# % 190 1012.847902
# % 191 1020.200373
# % 192 1035.752709
# % 193 1061.845254
# % 194 1049.085065
# % 195 1039.381615
# % 196 1025.917470
# % 197 1007.915794
# % 198 1045.414372
# % 199 1063.525281
# % 200 1043.379824
# % 201 1062.653106
# % 202 1010.373332
# % 203 1007.181177
# > Finished 203 generations with 1017445 distance calculations. GA Runtime = 17.5395 sec
# > Final distance: 956.307881
# > Final Route:
# Truck 0 [len = 15]: 0 --> 9 --> 3 --> 41 --> 12 --> 40 --> 39 --> 18 --> 23 --> 24 --> 17 --> 13 --> 5 --> 45 --> 10
# Truck 1 [len = 15]: 0 --> 11 --> 36 --> 14 --> 16 --> 38 --> 4 --> 21 --> 30 --> 27 --> 50 --> 33 --> 49 --> 15 --> 47
# Truck 2 [len = 5]: 0 --> 35 --> 28 --> 6 --> 25
# Truck 3 [len = 9]: 0 --> 46 --> 44 --> 29 --> 8 --> 48 --> 32 --> 43 --> 37
# Truck 4 [len = 11]: 0 --> 22 --> 42 --> 26 --> 20 --> 2 --> 34 --> 19 --> 31 --> 1 --> 7
# > Generation - Distance curve saved to fig/20211216_03_08_53.png.

# %% [markdown]
# 2. `mtsp100`

# %%
# !python main.py -d instances/mtsp100.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp100.txt
# 	>> 100 cities in total to be loaded
# > 100 cities loaded from instances/mtsp100.txt
# > Initial distance: 147092.648825
# > Starting running GA.
# 	>> cities = 100, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 141630.968205
# % 2 139721.802179
# % 3 133082.890287
# % 4 132934.529822
# % 5 129082.373269
# % 6 128463.599138
# % 7 125696.778710
# % 8 126014.288050
# % 9 120922.119973
# % 10 119682.495175
# % 11 117854.275506
# % 12 113074.198085
# % 13 111602.526723
# % 14 110830.987996
# % 15 107863.365694
# % 16 108051.699133
# % 17 109471.077494
# % 18 105156.825455
# % 19 103556.110055
# % 20 101852.781161
# % 21 100980.008188
# % 22 101855.140268
# % 23 101483.505797
# % 24 100670.019287
# % 25 99508.931031
# % 26 97004.210689
# % 27 97559.196060
# % 28 98393.066960
# % 29 98666.694892
# % 30 98616.164593
# % 31 97361.698226
# % 32 98653.433232
# % 33 97207.087885
# % 34 96199.656441
# % 35 97587.346939
# % 36 97602.528368
# % 37 98293.152271
# % 38 98205.448147
# % 39 100514.120617
# % 40 96145.717456
# % 41 96811.635834
# % 42 97039.917258
# % 43 97107.439076
# % 44 95641.436074
# % 45 98618.360403
# % 46 99068.234105
# % 47 95646.132871
# % 48 95562.956544
# % 49 95391.247332
# % 50 96169.898166
# % 51 96611.615142
# % 52 94931.369970
# % 53 96462.538869
# % 54 92222.544395
# % 55 89321.160764
# % 56 89306.636295
# % 57 87661.659418
# % 58 87674.126408
# % 59 89833.048626
# % 60 89716.230585
# % 61 87226.044091
# % 62 87673.242678
# % 63 89321.344665
# % 64 89933.612072
# % 65 92003.336652
# % 66 89591.704508
# % 67 90039.206860
# % 68 91087.530831
# % 69 91687.686257
# % 70 90695.098805
# % 71 88240.314917
# % 72 89902.433190
# % 73 92638.145246
# % 74 93315.778718
# % 75 92987.601416
# % 76 91967.381159
# % 77 91618.537592
# % 78 91306.645862
# % 79 89252.528385
# % 80 88524.053989
# % 81 89369.699844
# % 82 88403.073876
# % 83 85908.524534
# % 84 85386.933267
# % 85 84700.338396
# % 86 86133.069213
# % 87 87195.391694
# % 88 84813.610249
# % 89 88994.507586
# % 90 90031.742542
# % 91 89758.458924
# % 92 90904.101439
# % 93 90363.011176
# % 94 92073.930074
# % 95 90391.125278
# % 96 90548.175621
# % 97 90091.275582
# % 98 89324.492290
# % 99 89952.349711
# % 100 89319.765934
# % 101 91329.651213
# % 102 91165.029909
# % 103 90172.029382
# % 104 91163.611833
# % 105 90453.883915
# % 106 92138.488168
# % 107 92726.251082
# % 108 90879.250524
# % 109 92337.940970
# % 110 89825.915891
# % 111 90756.023224
# % 112 89721.331619
# % 113 90488.588147
# % 114 90364.666969
# % 115 90339.655859
# % 116 87772.160516
# % 117 91289.696922
# % 118 95221.066031
# % 119 93677.161770
# % 120 95479.058578
# % 121 95944.107789
# % 122 95642.185227
# % 123 95063.236157
# % 124 96858.351944
# % 125 90480.538348
# % 126 89487.101632
# % 127 89148.913803
# % 128 87651.342593
# % 129 85033.831977
# % 130 84008.866183
# % 131 84010.662888
# % 132 86138.540583
# % 133 88870.356431
# % 134 86501.663732
# % 135 85679.454794
# % 136 88019.157336
# % 137 89398.855096
# % 138 90049.440361
# % 139 89771.084642
# % 140 88586.198940
# % 141 89311.417771
# % 142 90272.874445
# % 143 88289.454968
# % 144 91831.848306
# % 145 91102.529752
# % 146 93443.053052
# % 147 93602.210556
# % 148 93381.132711
# % 149 95251.595959
# % 150 95226.611337
# % 151 94603.879912
# % 152 95902.609850
# % 153 96348.734104
# % 154 93633.310071
# % 155 94916.400107
# % 156 91207.431855
# % 157 94076.538208
# % 158 95582.079785
# % 159 93139.682111
# % 160 91405.808186
# % 161 94607.389954
# % 162 94633.065953
# % 163 94450.539438
# % 164 94341.591226
# % 165 94528.044280
# % 166 95479.566478
# % 167 92331.653337
# % 168 92385.228147
# % 169 95206.566742
# % 170 94996.346144
# % 171 96677.391314
# % 172 96344.524964
# % 173 97861.482956
# % 174 97442.345519
# % 175 94989.816162
# % 176 93677.086437
# % 177 96301.840852
# % 178 93117.597630
# % 179 95108.996425
# % 180 96915.205549
# % 181 97658.597640
# % 182 90530.402128
# % 183 92040.368350
# % 184 94092.857495
# % 185 91137.849670
# % 186 88541.934628
# % 187 88593.778983
# % 188 89677.578717
# % 189 92491.946738
# % 190 91349.440877
# % 191 92559.086264
# % 192 95922.488241
# % 193 94152.779424
# % 194 90090.169270
# % 195 91498.215625
# % 196 91460.588740
# % 197 94128.242799
# % 198 93151.247479
# % 199 94974.200373
# % 200 94738.183193
# % 201 90085.535970
# % 202 93940.941328
# % 203 95852.767713
# % 204 95657.594649
# % 205 95279.150919
# % 206 91890.993632
# % 207 92941.120083
# % 208 91871.584097
# % 209 91976.297189
# % 210 89362.374208
# % 211 92394.818160
# % 212 92002.881308
# > Finished 212 generations with 2005328 distance calculations. GA Runtime = 41.3678 sec
# > Final distance: 84008.866183
# > Final Route:
# Truck 0 [len = 27]: 0 --> 96 --> 89 --> 16 --> 10 --> 51 --> 80 --> 69 --> 65 --> 30 --> 95 --> 52 --> 2 --> 1 --> 47 --> 39 --> 67 --> 15 --> 40 --> 23 --> 62 --> 48 --> 49 --> 45 --> 37 --> 31 --> 88
# Truck 1 [len = 22]: 0 --> 53 --> 3 --> 43 --> 59 --> 4 --> 82 --> 18 --> 27 --> 94 --> 54 --> 29 --> 70 --> 92 --> 42 --> 36 --> 8 --> 46 --> 5 --> 77 --> 83 --> 87
# Truck 2 [len = 13]: 0 --> 26 --> 73 --> 41 --> 57 --> 35 --> 28 --> 56 --> 38 --> 78 --> 72 --> 14 --> 7
# Truck 3 [len = 14]: 0 --> 60 --> 24 --> 34 --> 99 --> 86 --> 58 --> 85 --> 79 --> 33 --> 74 --> 66 --> 93 --> 97
# Truck 4 [len = 28]: 0 --> 12 --> 76 --> 90 --> 9 --> 25 --> 91 --> 81 --> 75 --> 71 --> 64 --> 21 --> 22 --> 6 --> 32 --> 63 --> 84 --> 61 --> 20 --> 19 --> 98 --> 17 --> 50 --> 11 --> 55 --> 13 --> 44 --> 68
# > Generation - Distance curve saved to fig/20211216_02_44_20.png.

# %% [markdown]
# 3. `mtsp150`

# %%
# !python main.py -d instances/mtsp150.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp150.txt
# 	>> 150 cities in total to be loaded
# > 150 cities loaded from instances/mtsp150.txt
# > Initial distance: 279132.622633
# > Starting running GA.
# 	>> cities = 150, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 275779.025309
# % 2 270967.076345
# % 3 267996.146581
# % 4 262309.369888
# % 5 258609.544859
# % 6 257303.072838
# % 7 255629.358534
# % 8 254931.557488
# % 9 253595.483366
# % 10 251329.319234
# % 11 249457.561001
# % 12 246707.748550
# % 13 244423.290308
# % 14 240218.448621
# % 15 240414.661553
# % 16 234182.234932
# % 17 230460.749048
# % 18 229374.366350
# % 19 226837.264172
# % 20 222954.330259
# % 21 220732.837832
# % 22 218344.822750
# % 23 216985.214310
# % 24 215355.078420
# % 25 214436.788770
# % 26 212257.890466
# % 27 209491.270512
# % 28 208363.121290
# % 29 204429.878797
# % 30 205384.876760
# % 31 206716.426913
# % 32 204467.524338
# % 33 204873.210732
# % 34 204088.458479
# % 35 204627.163015
# % 36 204408.761390
# % 37 200889.708962
# % 38 200688.844032
# % 39 201118.170882
# % 40 198802.550583
# % 41 198017.987366
# % 42 195297.380106
# % 43 192940.280268
# % 44 191831.892456
# % 45 190253.115727
# % 46 189984.772010
# % 47 187359.053456
# % 48 187637.944953
# % 49 186073.397969
# % 50 183193.007557
# % 51 183345.198869
# % 52 180154.618186
# % 53 177866.183959
# % 54 179654.260445
# % 55 173246.105435
# % 56 173575.858035
# % 57 172157.087310
# % 58 173508.535808
# % 59 171835.233334
# % 60 173396.176128
# % 61 171057.741214
# % 62 169183.657554
# % 63 168751.443533
# % 64 166800.790163
# % 65 170236.316530
# % 66 169108.114353
# % 67 165119.782351
# % 68 164198.053916
# % 69 166121.412423
# % 70 164111.631072
# % 71 160655.349001
# % 72 156916.945200
# % 73 157353.712288
# % 74 158356.452906
# % 75 157975.119587
# % 76 160328.243060
# % 77 157611.615234
# % 78 159373.731598
# % 79 159503.146723
# % 80 160164.958536
# % 81 160174.628808
# % 82 156522.488200
# % 83 157007.192510
# % 84 153147.975412
# % 85 151054.933629
# % 86 153833.328498
# % 87 150691.081482
# % 88 152021.527516
# % 89 151768.546361
# % 90 148408.537476
# % 91 150996.721185
# % 92 152167.599836
# % 93 153160.823355
# % 94 152997.100602
# % 95 152828.593328
# % 96 151975.910776
# % 97 152365.241183
# % 98 153492.802516
# % 99 154161.706717
# % 100 154076.787992
# % 101 153744.868593
# % 102 155966.009355
# % 103 158653.027107
# % 104 158944.097753
# % 105 157380.256447
# % 106 157768.213576
# % 107 157421.638565
# % 108 156018.690710
# % 109 156043.121594
# % 110 154664.943605
# % 111 152032.650209
# % 112 153922.641234
# % 113 154778.371624
# % 114 152464.987154
# % 115 150799.400481
# % 116 152071.446943
# % 117 153645.121195
# % 118 152001.901105
# % 119 153469.024983
# % 120 150611.110307
# % 121 153397.410955
# % 122 153548.844627
# % 123 154287.892646
# % 124 153926.156635
# % 125 152687.473011
# % 126 153100.714739
# % 127 152133.484006
# % 128 153571.780015
# % 129 155456.361774
# % 130 152580.340857
# % 131 152058.592531
# % 132 151619.581796
# % 133 152095.312807
# % 134 151743.021688
# % 135 150664.066707
# % 136 151947.746681
# % 137 152732.051113
# % 138 152825.341058
# % 139 155053.955611
# % 140 155927.952760
# % 141 153787.138857
# % 142 156587.139518
# % 143 150436.373039
# % 144 150182.538614
# % 145 152328.467830
# % 146 152856.017384
# % 147 153335.491517
# % 148 152989.775462
# % 149 155830.833789
# % 150 157253.829283
# % 151 156802.090318
# % 152 157727.299544
# % 153 157771.900518
# % 154 158533.881572
# % 155 157007.514525
# % 156 158282.264907
# % 157 155510.738937
# % 158 155650.812901
# % 159 154483.661631
# % 160 156188.413313
# % 161 157126.129322
# % 162 156175.700732
# % 163 155277.514747
# % 164 154045.004284
# % 165 153278.349359
# % 166 155314.764884
# % 167 156043.082348
# % 168 152730.818546
# % 169 153414.754194
# % 170 152411.047658
# % 171 149207.653063
# % 172 150719.600952
# % 173 151430.070641
# % 174 154790.389037
# % 175 153857.358586
# % 176 151210.684274
# % 177 150584.251651
# % 178 150404.264792
# % 179 149196.156225
# % 180 149929.152711
# % 181 148164.538943
# % 182 147495.262158
# % 183 151332.415655
# % 184 151003.022955
# % 185 151165.769898
# % 186 150830.114921
# % 187 152192.176647
# % 188 151531.595288
# % 189 149992.070088
# % 190 149632.328325
# % 191 146843.325510
# % 192 145687.838602
# % 193 147328.710265
# % 194 146454.259769
# % 195 147158.799558
# % 196 147503.131637
# % 197 148002.142388
# % 198 144677.515988
# % 199 145955.518148
# % 200 145455.055701
# % 201 146701.547431
# % 202 144024.033831
# % 203 144375.610538
# % 204 143795.097719
# % 205 146438.053069
# % 206 148125.435328
# % 207 147299.252577
# % 208 146790.237446
# % 209 150141.218436
# % 210 148552.946084
# % 211 150427.930047
# % 212 148808.432057
# % 213 149013.345884
# % 214 145812.568474
# > Finished 214 generations with 3001306 distance calculations. GA Runtime = 75.0554 sec
# > Final distance: 143795.097719
# > Final Route:
# Truck 0 [len = 48]: 0 --> 12 --> 135 --> 104 --> 28 --> 66 --> 75 --> 94 --> 80 --> 4 --> 146 --> 63 --> 39 --> 74 --> 89 --> 96 --> 25 --> 15 --> 93 --> 37 --> 133 --> 58 --> 143 --> 81 --> 72 --> 50 --> 76 --> 109 --> 8 --> 98 --> 112 --> 88 --> 142 --> 117 --> 123 --> 17 --> 9 --> 52 --> 136 --> 3 --> 69 --> 121 --> 130 --> 60 --> 144 --> 148 --> 59 --> 19
# Truck 1 [len = 31]: 0 --> 53 --> 30 --> 41 --> 5 --> 101 --> 62 --> 71 --> 10 --> 137 --> 92 --> 87 --> 110 --> 18 --> 48 --> 138 --> 32 --> 100 --> 47 --> 61 --> 16 --> 124 --> 106 --> 13 --> 55 --> 86 --> 40 --> 111 --> 45 --> 99 --> 116
# Truck 2 [len = 27]: 0 --> 134 --> 145 --> 33 --> 68 --> 125 --> 64 --> 102 --> 21 --> 56 --> 127 --> 114 --> 38 --> 54 --> 120 --> 43 --> 122 --> 70 --> 108 --> 118 --> 128 --> 65 --> 7 --> 132 --> 44 --> 78 --> 46
# Truck 3 [len = 29]: 0 --> 97 --> 73 --> 23 --> 35 --> 90 --> 83 --> 126 --> 140 --> 20 --> 103 --> 42 --> 113 --> 26 --> 77 --> 105 --> 51 --> 29 --> 85 --> 79 --> 22 --> 27 --> 91 --> 147 --> 24 --> 82 --> 95 --> 115 --> 36
# Truck 4 [len = 19]: 0 --> 149 --> 57 --> 34 --> 131 --> 129 --> 2 --> 84 --> 67 --> 141 --> 139 --> 107 --> 49 --> 1 --> 31 --> 14 --> 119 --> 11 --> 6
# > Generation - Distance curve saved to fig/20211216_02_45_03.png.

# %% [markdown]
# 4. `pr76`

# %%
# !python main.py -d instances/pr76.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr76.txt
# 	>> 76 cities in total to be loaded
# > 76 cities loaded from instances/pr76.txt
# > Initial distance: 550731.653223
# > Starting running GA.
# 	>> cities = 76, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 539199.391934
# % 2 528184.655279
# % 3 505632.878458
# % 4 501802.855909
# % 5 492088.709152
# % 6 488699.324960
# % 7 471185.042812
# % 8 472262.371071
# % 9 454577.071838
# % 10 464880.456428
# % 11 461862.570270
# % 12 438928.775904
# % 13 448325.800848
# % 14 450243.636983
# % 15 451331.501357
# % 16 453765.651929
# % 17 447656.281101
# % 18 453441.850488
# % 19 442080.986885
# % 20 436064.107955
# % 21 437495.102007
# % 22 434941.362278
# % 23 431936.567024
# % 24 422963.168137
# % 25 426493.027154
# % 26 423735.251905
# % 27 419140.194176
# % 28 414095.130713
# % 29 406088.784934
# % 30 407099.722339
# % 31 406806.412367
# % 32 406543.679847
# % 33 402037.211587
# % 34 402140.158600
# % 35 399378.724191
# % 36 403874.236882
# % 37 400976.866155
# % 38 395148.818255
# % 39 394666.031684
# % 40 395963.152864
# % 41 392143.680428
# % 42 390531.606350
# % 43 392668.150031
# % 44 396736.367057
# % 45 398380.929651
# % 46 386219.936314
# % 47 379777.404299
# % 48 375445.888793
# % 49 375342.635877
# % 50 367614.821715
# % 51 381536.382332
# % 52 367969.035911
# % 53 375180.796630
# % 54 376021.859707
# % 55 380041.067468
# % 56 368584.158180
# % 57 379429.346941
# % 58 391136.217303
# % 59 379168.052225
# % 60 371715.939760
# % 61 368494.636110
# % 62 373498.623345
# % 63 374063.949417
# % 64 363389.502695
# % 65 358906.897408
# % 66 372290.835248
# % 67 375867.965213
# % 68 358047.680335
# % 69 367732.795422
# % 70 367414.145199
# % 71 376679.679238
# % 72 379948.004743
# % 73 382265.280216
# % 74 383882.944186
# % 75 378344.581351
# % 76 383515.609454
# % 77 385477.680720
# % 78 385482.164822
# % 79 383784.557747
# % 80 378569.807604
# % 81 378929.095606
# % 82 378357.011583
# % 83 376354.483486
# % 84 379472.223554
# % 85 392436.569179
# % 86 381198.652676
# % 87 390854.809538
# % 88 392518.271546
# % 89 383307.438941
# % 90 397593.242650
# % 91 396686.644350
# % 92 392285.096273
# % 93 397061.753500
# % 94 403677.597669
# % 95 405244.236282
# % 96 395898.580600
# % 97 388651.999213
# % 98 401205.773402
# % 99 379230.696746
# % 100 381955.854416
# % 101 386556.543631
# % 102 384172.360362
# % 103 394164.201701
# % 104 383167.448729
# % 105 390456.562197
# % 106 383095.634563
# % 107 398193.854537
# % 108 400100.533176
# % 109 392096.578075
# % 110 392290.591699
# % 111 380579.801677
# % 112 380748.481418
# % 113 396021.079667
# % 114 389382.932034
# % 115 397108.076126
# % 116 388647.910036
# % 117 387205.747282
# % 118 368336.606444
# % 119 374376.295086
# % 120 371149.618381
# % 121 372472.320358
# % 122 376927.108933
# % 123 368327.547397
# % 124 372408.650253
# % 125 386220.347203
# % 126 378619.372553
# % 127 384432.551298
# % 128 378171.311940
# % 129 382557.939238
# % 130 385824.426204
# % 131 375305.649459
# % 132 370189.270751
# % 133 365783.548478
# % 134 371998.141136
# % 135 367165.394589
# % 136 377962.043127
# % 137 380336.139799
# % 138 389314.752273
# % 139 376678.953417
# % 140 387370.887260
# % 141 369194.788712
# % 142 377534.291111
# % 143 369737.768516
# % 144 378670.055585
# % 145 375043.081477
# % 146 378847.427430
# % 147 375372.384142
# % 148 389897.521863
# % 149 378996.380718
# % 150 375804.939682
# % 151 379323.064326
# % 152 356671.305181
# % 153 362734.538673
# % 154 356075.231838
# % 155 350603.770204
# % 156 346546.705338
# % 157 352312.023880
# % 158 359638.418549
# % 159 367300.438876
# % 160 355709.026845
# % 161 355368.115197
# % 162 356473.048983
# % 163 356374.503226
# % 164 366035.951862
# % 165 362466.289747
# % 166 368601.191101
# % 167 371798.337575
# % 168 359801.612062
# % 169 357847.087945
# % 170 359128.788526
# % 171 363865.734804
# % 172 370527.764277
# % 173 348259.477939
# % 174 353179.156787
# % 175 364734.998015
# % 176 375763.419992
# % 177 358476.526976
# % 178 373522.503855
# % 179 369220.295127
# % 180 378644.488147
# % 181 384052.041957
# % 182 393888.030762
# % 183 393329.470841
# % 184 386997.239997
# % 185 395081.291423
# % 186 386271.737268
# % 187 396208.501165
# % 188 402159.290378
# % 189 404323.625336
# % 190 401944.978626
# % 191 392133.943718
# % 192 397846.110898
# % 193 398846.422184
# % 194 387177.590922
# % 195 382367.845933
# % 196 381338.441416
# % 197 374941.846816
# % 198 385053.994832
# % 199 378080.008089
# % 200 385176.948220
# % 201 381069.407168
# % 202 396201.298124
# % 203 388091.195150
# % 204 374544.939119
# % 205 372827.885446
# % 206 380174.235412
# % 207 364436.360489
# % 208 359108.752068
# % 209 353238.754630
# > Finished 209 generations with 1522400 distance calculations. GA Runtime = 28.0864 sec
# > Final distance: 346546.705338
# > Final Route:
# Truck 0 [len = 19]: 0 --> 1 --> 46 --> 43 --> 39 --> 58 --> 56 --> 72 --> 62 --> 59 --> 25 --> 23 --> 26 --> 34 --> 51 --> 61 --> 50 --> 57 --> 42
# Truck 1 [len = 6]: 0 --> 75 --> 74 --> 20 --> 45 --> 49
# Truck 2 [len = 24]: 0 --> 8 --> 4 --> 32 --> 66 --> 69 --> 48 --> 65 --> 64 --> 70 --> 71 --> 55 --> 52 --> 63 --> 60 --> 41 --> 16 --> 12 --> 73 --> 15 --> 17 --> 10 --> 9 --> 31
# Truck 3 [len = 17]: 0 --> 11 --> 5 --> 40 --> 37 --> 28 --> 24 --> 38 --> 35 --> 36 --> 14 --> 13 --> 54 --> 53 --> 3 --> 6 --> 7
# Truck 4 [len = 14]: 0 --> 44 --> 47 --> 33 --> 27 --> 18 --> 19 --> 21 --> 22 --> 67 --> 68 --> 29 --> 30 --> 2
# > Generation - Distance curve saved to fig/20211216_02_46_20.png.

# %% [markdown]
# 5. `pr152`

# %%
# !python main.py -d instances/pr152.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr152.txt
# 	>> 152 cities in total to be loaded
# > 152 cities loaded from instances/pr152.txt
# > Initial distance: 1006289.620068
# > Starting running GA.
# 	>> cities = 152, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 986787.902669
# % 2 982026.081392
# % 3 954979.264776
# % 4 964377.519461
# % 5 950421.274717
# % 6 942655.187701
# % 7 934613.361220
# % 8 915364.257624
# % 9 918664.712710
# % 10 896670.958319
# % 11 890174.490602
# % 12 895700.621858
# % 13 875968.186062
# % 14 867983.316001
# % 15 866449.022378
# % 16 872038.087027
# % 17 861478.632298
# % 18 854266.605132
# % 19 843863.873856
# % 20 834603.220905
# % 21 819250.575316
# % 22 811500.931685
# % 23 805117.604302
# % 24 797857.901356
# % 25 796083.823311
# % 26 775628.141219
# % 27 762037.885616
# % 28 764813.267507
# % 29 759462.930559
# % 30 759222.572447
# % 31 744506.527219
# % 32 733078.873495
# % 33 727727.732942
# % 34 730791.714590
# % 35 721103.639208
# % 36 712523.515007
# % 37 720106.009060
# % 38 711132.638468
# % 39 707061.519473
# % 40 709954.190830
# % 41 700115.072564
# % 42 685556.099045
# % 43 684166.217485
# % 44 686449.950467
# % 45 688192.245870
# % 46 681926.480408
# % 47 678812.776494
# % 48 664810.751260
# % 49 679830.201933
# % 50 671371.458002
# % 51 666923.516535
# % 52 667559.570128
# % 53 669017.592956
# % 54 651186.864494
# % 55 658101.810403
# % 56 667561.284636
# % 57 658301.156902
# % 58 633694.441831
# % 59 643374.512655
# % 60 648217.801287
# % 61 644527.350826
# % 62 644642.781605
# % 63 654530.663643
# % 64 645124.766982
# % 65 646371.856858
# % 66 642273.355430
# % 67 637778.020858
# % 68 652343.532929
# % 69 637078.509135
# % 70 656048.086759
# % 71 651508.787408
# % 72 656452.484015
# % 73 661861.219565
# % 74 649583.448555
# % 75 654245.372106
# % 76 668128.277165
# % 77 661746.329056
# % 78 654909.718407
# % 79 649453.534553
# % 80 645531.296576
# % 81 637894.856880
# % 82 620469.422455
# % 83 636091.671269
# % 84 636776.950429
# % 85 632638.160202
# % 86 629795.923193
# % 87 630736.422639
# % 88 623056.038517
# % 89 640271.165636
# % 90 615025.134640
# % 91 589626.474633
# % 92 589959.551671
# % 93 604219.909088
# % 94 596977.961628
# % 95 611355.619108
# % 96 595972.063144
# % 97 595237.023580
# % 98 589587.030655
# % 99 602647.052781
# % 100 599993.387050
# % 101 598847.497146
# % 102 600683.676411
# % 103 579437.314102
# % 104 585634.474860
# % 105 597737.513565
# % 106 602795.481602
# % 107 607080.291456
# % 108 605459.687574
# % 109 608443.475795
# % 110 611776.638964
# % 111 615412.996563
# % 112 610634.206753
# % 113 607208.688005
# % 114 610148.805909
# % 115 611975.282303
# % 116 613073.038979
# % 117 612626.369387
# % 118 610289.052641
# % 119 604593.183630
# % 120 613760.649076
# % 121 600574.954825
# % 122 619989.264056
# % 123 620815.069941
# % 124 608682.007952
# % 125 608514.489311
# % 126 605058.761316
# % 127 602935.839018
# % 128 592837.143849
# % 129 591834.999177
# % 130 586409.569979
# % 131 599984.888838
# % 132 582864.871092
# % 133 589161.277550
# % 134 588508.232689
# % 135 582480.702035
# % 136 594984.898721
# % 137 587947.376993
# % 138 580524.611591
# % 139 572436.661336
# % 140 572805.754499
# % 141 565368.887895
# % 142 588764.754564
# % 143 568592.675992
# % 144 581634.908152
# % 145 582391.955099
# % 146 581917.549331
# % 147 591617.143249
# % 148 586936.182857
# % 149 588196.316289
# % 150 587447.245242
# % 151 590667.771836
# % 152 585562.366679
# % 153 563361.588731
# % 154 572140.490947
# % 155 566497.333842
# % 156 573263.949059
# % 157 568011.450288
# % 158 562812.110798
# % 159 556386.009434
# % 160 554972.291406
# % 161 549996.273698
# % 162 561693.077732
# % 163 551719.288160
# % 164 567491.023234
# % 165 560101.306605
# % 166 572571.549877
# % 167 586735.418403
# % 168 579574.676274
# % 169 579112.162338
# % 170 586060.302523
# % 171 590139.302937
# % 172 591806.414693
# % 173 595850.939864
# % 174 604555.703563
# % 175 584274.006007
# % 176 584150.568720
# % 177 571596.742471
# % 178 577517.646325
# % 179 577962.565092
# % 180 580973.876246
# % 181 583707.643652
# % 182 586791.819446
# % 183 575355.833860
# % 184 566057.128683
# % 185 570937.048267
# % 186 565024.703468
# % 187 572578.112366
# % 188 568945.767106
# % 189 577473.954412
# % 190 571637.174045
# % 191 576877.529057
# % 192 565218.357432
# % 193 572885.105245
# % 194 568782.383061
# % 195 561292.884270
# % 196 557247.669037
# % 197 545557.138612
# % 198 537497.156920
# % 199 539735.137231
# % 200 538507.087328
# % 201 545997.675458
# % 202 521061.318641
# % 203 520666.566801
# % 204 540309.095100
# % 205 542005.824970
# % 206 532754.810866
# % 207 547488.490981
# % 208 544989.071347
# % 209 535292.417332
# % 210 547450.413371
# % 211 545314.512016
# % 212 547394.199456
# % 213 554585.787101
# % 214 544958.563261
# % 215 565755.423720
# > Finished 215 generations with 3053544 distance calculations. GA Runtime = 79.1620 sec
# > Final distance: 520666.566801
# > Final Route:
# Truck 0 [len = 25]: 0 --> 95 --> 67 --> 66 --> 138 --> 117 --> 119 --> 113 --> 57 --> 23 --> 20 --> 6 --> 19 --> 38 --> 28 --> 37 --> 27 --> 8 --> 30 --> 81 --> 91 --> 97 --> 71 --> 88 --> 32
# Truck 1 [len = 39]: 0 --> 12 --> 10 --> 9 --> 5 --> 147 --> 131 --> 144 --> 44 --> 54 --> 51 --> 60 --> 85 --> 83 --> 17 --> 92 --> 93 --> 87 --> 65 --> 107 --> 18 --> 7 --> 16 --> 105 --> 82 --> 139 --> 104 --> 101 --> 112 --> 74 --> 94 --> 115 --> 43 --> 100 --> 47 --> 132 --> 63 --> 58 --> 109
# Truck 2 [len = 35]: 0 --> 13 --> 14 --> 2 --> 26 --> 133 --> 134 --> 111 --> 68 --> 77 --> 90 --> 126 --> 130 --> 145 --> 84 --> 62 --> 99 --> 89 --> 79 --> 143 --> 121 --> 150 --> 127 --> 123 --> 129 --> 118 --> 64 --> 45 --> 52 --> 59 --> 42 --> 98 --> 102 --> 39 --> 21
# Truck 3 [len = 24]: 0 --> 11 --> 69 --> 78 --> 53 --> 70 --> 137 --> 140 --> 141 --> 116 --> 135 --> 110 --> 76 --> 49 --> 46 --> 80 --> 103 --> 41 --> 55 --> 114 --> 72 --> 35 --> 31 --> 34
# Truck 4 [len = 33]: 0 --> 33 --> 22 --> 125 --> 48 --> 75 --> 124 --> 149 --> 151 --> 122 --> 146 --> 148 --> 128 --> 120 --> 136 --> 142 --> 86 --> 50 --> 56 --> 61 --> 40 --> 96 --> 108 --> 106 --> 73 --> 25 --> 24 --> 29 --> 4 --> 1 --> 3 --> 36 --> 15
# > Generation - Distance curve saved to fig/20211216_02_46_50.png.

# %% [markdown]
# 6. `pr226`

# %%
# !python main.py -d instances/pr226.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr226.txt
# 	>> 226 cities in total to be loaded
# > 226 cities loaded from instances/pr226.txt
# > Initial distance: 1628419.641732
# > Starting running GA.
# 	>> cities = 226, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1601570.356034
# % 2 1580326.404687
# % 3 1565064.507308
# % 4 1571967.344286
# % 5 1559627.041023
# % 6 1542794.824623
# % 7 1532044.339090
# % 8 1525562.736147
# % 9 1512394.644665
# % 10 1483473.132261
# % 11 1459555.032887
# % 12 1464293.678709
# % 13 1452143.550664
# % 14 1438440.860622
# % 15 1423619.271173
# % 16 1424465.966078
# % 17 1407231.403708
# % 18 1405349.544911
# % 19 1405086.165629
# % 20 1395261.277775
# % 21 1382199.948275
# % 22 1366189.002539
# % 23 1368526.422904
# % 24 1372033.023496
# % 25 1357356.200949
# % 26 1349006.489564
# % 27 1363071.158975
# % 28 1341454.237393
# % 29 1330920.764117
# % 30 1327669.342668
# % 31 1327901.007519
# % 32 1313673.565881
# % 33 1313308.944583
# % 34 1321126.996991
# % 35 1315191.321403
# % 36 1301124.061693
# % 37 1309551.886389
# % 38 1306173.541215
# % 39 1311416.201288
# % 40 1292243.080420
# % 41 1288353.821276
# % 42 1274468.074829
# % 43 1260036.121163
# % 44 1248251.062983
# % 45 1245046.804601
# % 46 1242440.893897
# % 47 1228260.974521
# % 48 1233126.496596
# % 49 1235169.109404
# % 50 1233098.191108
# % 51 1244268.411868
# % 52 1221582.720568
# % 53 1208371.767839
# % 54 1186409.564202
# % 55 1185172.298938
# % 56 1180033.695980
# % 57 1178716.328570
# % 58 1177995.022804
# % 59 1168269.835458
# % 60 1163029.099244
# % 61 1161204.170503
# % 62 1150815.498880
# % 63 1140750.979096
# % 64 1144209.597804
# % 65 1144117.686228
# % 66 1130461.283817
# % 67 1140643.881442
# % 68 1128349.135256
# % 69 1118759.741484
# % 70 1100540.245917
# % 71 1103120.323806
# % 72 1091400.911743
# % 73 1084994.801909
# % 74 1078731.473901
# % 75 1099245.614125
# % 76 1077691.134525
# % 77 1083916.092485
# % 78 1071502.233444
# % 79 1049877.842671
# % 80 1049149.627259
# % 81 1044771.355164
# % 82 1042768.669525
# % 83 1026786.980275
# % 84 1005395.068642
# % 85 1033583.626411
# % 86 1019920.859908
# % 87 1021468.288965
# % 88 1031453.559453
# % 89 1036203.651881
# % 90 1026983.814966
# % 91 1038467.968573
# % 92 1024163.554767
# % 93 1035518.946234
# % 94 1031217.136767
# % 95 1015000.861704
# % 96 1018780.697796
# % 97 1023972.767422
# % 98 1008712.417141
# % 99 1007466.722157
# % 100 1017067.513208
# % 101 989238.353988
# % 102 1004991.964944
# % 103 1000284.873354
# % 104 1008734.843129
# % 105 1007332.540251
# % 106 1009013.867211
# % 107 1004674.279289
# % 108 1001157.572306
# % 109 1016683.192965
# % 110 1015864.988215
# % 111 1019934.247027
# % 112 1008014.783758
# % 113 1009482.918750
# % 114 1007784.310475
# % 115 1015453.754630
# % 116 1031147.313677
# % 117 1040444.089284
# % 118 1029396.962725
# % 119 1029965.794597
# % 120 1020072.901543
# % 121 1020072.901543
# % 122 1014973.494358
# % 123 1014288.638587
# % 124 1012732.243192
# % 125 1006013.491585
# % 126 1010880.363495
# % 127 993348.135469
# % 128 1011133.201845
# % 129 1006235.105482
# % 130 1001979.465824
# % 131 1007172.709672
# % 132 1004982.234510
# % 133 1018757.206881
# % 134 1015257.947298
# % 135 1004921.570731
# % 136 999834.610278
# % 137 998369.396901
# % 138 997922.433091
# % 139 991521.203021
# % 140 987193.464103
# % 141 994940.279401
# % 142 982944.825266
# % 143 990976.337457
# % 144 978265.279595
# % 145 976849.618641
# % 146 981101.855773
# % 147 971819.843902
# % 148 962042.828897
# % 149 955503.690516
# % 150 956622.158774
# % 151 962521.213542
# % 152 959070.510342
# % 153 966126.780806
# % 154 970736.665736
# % 155 987429.499755
# % 156 979416.437223
# % 157 991097.016508
# % 158 990925.206271
# % 159 1000235.513143
# % 160 977200.561033
# % 161 984928.666017
# % 162 1001535.007165
# % 163 992287.797346
# % 164 996185.371115
# % 165 980455.248522
# % 166 997678.741585
# % 167 985944.592647
# % 168 993146.856603
# % 169 982023.157808
# % 170 973929.173237
# % 171 975212.441210
# % 172 989453.687330
# % 173 969889.400898
# % 174 974165.385078
# % 175 977432.669557
# % 176 972916.713173
# % 177 979268.153113
# % 178 972465.350344
# % 179 981868.214000
# % 180 970422.861219
# % 181 978609.950261
# % 182 983885.695261
# % 183 971814.403328
# % 184 965475.064657
# % 185 960285.868296
# % 186 969088.088826
# % 187 978208.984879
# % 188 971128.864422
# % 189 984907.577066
# % 190 982995.127691
# % 191 969105.911377
# % 192 966276.743681
# % 193 975492.964266
# % 194 977082.498604
# % 195 988527.116872
# % 196 973998.205912
# % 197 972065.006025
# % 198 957982.488913
# % 199 961260.566416
# % 200 962987.084051
# % 201 970297.163494
# % 202 983058.976623
# % 203 962630.043768
# % 204 962301.281911
# % 205 969404.449022
# % 206 983296.707178
# % 207 992360.020212
# % 208 977201.150692
# % 209 1004850.524850
# % 210 982805.490703
# % 211 995233.669062
# % 212 981590.074696
# % 213 989569.128317
# % 214 988543.937306
# % 215 982071.976810
# % 216 998444.910880
# % 217 990268.194459
# > Finished 217 generations with 4536980 distance calculations. GA Runtime = 158.0449 sec
# > Final distance: 955503.690516
# > Final Route:
# Truck 0 [len = 41]: 0 --> 171 --> 159 --> 164 --> 176 --> 156 --> 185 --> 178 --> 124 --> 122 --> 220 --> 203 --> 206 --> 208 --> 163 --> 188 --> 90 --> 42 --> 36 --> 29 --> 47 --> 100 --> 37 --> 30 --> 22 --> 209 --> 214 --> 219 --> 120 --> 85 --> 125 --> 126 --> 117 --> 69 --> 84 --> 81 --> 77 --> 59 --> 8 --> 6 --> 11
# Truck 1 [len = 40]: 0 --> 14 --> 51 --> 49 --> 50 --> 116 --> 75 --> 217 --> 87 --> 147 --> 182 --> 41 --> 53 --> 222 --> 223 --> 224 --> 110 --> 135 --> 218 --> 129 --> 207 --> 165 --> 160 --> 145 --> 39 --> 40 --> 46 --> 99 --> 105 --> 212 --> 221 --> 201 --> 113 --> 2 --> 82 --> 68 --> 67 --> 107 --> 127 --> 106
# Truck 2 [len = 80]: 0 --> 56 --> 155 --> 162 --> 20 --> 38 --> 21 --> 104 --> 91 --> 119 --> 202 --> 189 --> 181 --> 158 --> 150 --> 152 --> 187 --> 157 --> 167 --> 96 --> 26 --> 24 --> 35 --> 48 --> 103 --> 136 --> 33 --> 52 --> 64 --> 62 --> 109 --> 205 --> 121 --> 133 --> 139 --> 173 --> 175 --> 89 --> 27 --> 92 --> 138 --> 143 --> 74 --> 12 --> 1 --> 71 --> 66 --> 70 --> 144 --> 149 --> 102 --> 78 --> 10 --> 17 --> 31 --> 137 --> 197 --> 134 --> 204 --> 34 --> 79 --> 60 --> 58 --> 25 --> 196 --> 118 --> 199 --> 128 --> 195 --> 198 --> 172 --> 130 --> 200 --> 193 --> 192 --> 111 --> 115 --> 132 --> 97 --> 216
# Truck 3 [len = 37]: 0 --> 54 --> 184 --> 61 --> 7 --> 55 --> 32 --> 86 --> 153 --> 98 --> 191 --> 170 --> 154 --> 161 --> 148 --> 93 --> 180 --> 194 --> 190 --> 225 --> 123 --> 213 --> 210 --> 179 --> 168 --> 166 --> 183 --> 177 --> 141 --> 186 --> 95 --> 19 --> 28 --> 108 --> 73 --> 76 --> 5
# Truck 4 [len = 32]: 0 --> 13 --> 57 --> 15 --> 83 --> 211 --> 9 --> 4 --> 112 --> 114 --> 16 --> 80 --> 72 --> 3 --> 131 --> 151 --> 174 --> 169 --> 146 --> 88 --> 43 --> 44 --> 101 --> 140 --> 18 --> 65 --> 63 --> 215 --> 45 --> 94 --> 142 --> 23
# > Generation - Distance curve saved to fig/20211216_02_48_11.png.

# %% [markdown]
# ## xxx Algorithm (to compare with baseline)

# %% [markdown]
# 1. Run xxx on the `mtsp51` instance:

# %%
# !python main.py -d instances/mtsp51.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 2. `mtsp100`

# %%
# !python main.py -d instances/mtsp100.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 3. `mtsp150`

# %%
# !python main.py -d instances/mtsp150.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 4. `pr76`

# %%
# !python main.py -d instances/pr76.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 5. `pr152`

# %%
# !python main.py -d instances/pr152.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 6. `pr226`

# %%
# !python main.py -d instances/pr226.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# ## Statistical Comparison

# %% [markdown]
# 1. As an example, run baseline multiple indenpendent times on the `mtsp51` instance

# %%
# !python runMultiple.py -d instances/mtsp51.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# Out:
# >>> Total independent runs = 30 <<<
# ------------------------------------------------------------------------------------------------------
# Round 1
# ------------------------------------------------------------------------------------------------------
# Round 2
# ------------------------------------------------------------------------------------------------------
# Round 3
# ------------------------------------------------------------------------------------------------------
# Round 4
# ------------------------------------------------------------------------------------------------------
# Round 5
# ------------------------------------------------------------------------------------------------------
# Round 6
# ------------------------------------------------------------------------------------------------------
# Round 7
# ------------------------------------------------------------------------------------------------------
# Round 8
# ------------------------------------------------------------------------------------------------------
# Round 9
# ------------------------------------------------------------------------------------------------------
# Round 10
# ------------------------------------------------------------------------------------------------------
# Round 11
# ------------------------------------------------------------------------------------------------------
# Round 12
# ------------------------------------------------------------------------------------------------------
# Round 13
# ------------------------------------------------------------------------------------------------------
# Round 14
# ------------------------------------------------------------------------------------------------------
# Round 15
# ------------------------------------------------------------------------------------------------------
# Round 16
# ------------------------------------------------------------------------------------------------------
# Round 17
# ------------------------------------------------------------------------------------------------------
# Round 18
# ------------------------------------------------------------------------------------------------------
# Round 19
# ------------------------------------------------------------------------------------------------------
# Round 20
# ------------------------------------------------------------------------------------------------------
# Round 21
# ------------------------------------------------------------------------------------------------------
# Round 22
# ------------------------------------------------------------------------------------------------------
# Round 23
# ------------------------------------------------------------------------------------------------------
# Round 24
# ------------------------------------------------------------------------------------------------------
# Round 25
# ------------------------------------------------------------------------------------------------------
# Round 26
# ------------------------------------------------------------------------------------------------------
# Round 27
# ------------------------------------------------------------------------------------------------------
# Round 28
# ------------------------------------------------------------------------------------------------------
# Round 29
# ------------------------------------------------------------------------------------------------------
# Round 30
# ------------------------------------------------------------------------------------------------------
# >>> 30 runs all finished <<<

# %%
# !python runMultiple.py -d instances/mtsp100.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %%
# !python runMultiple.py -d instances/mtsp150.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %%
# !python runMultiple.py -d instances/pr76.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %%
# !python runMultiple.py -d instances/pr152.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %%
# !python runMultiple.py -d instances/pr226.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %% [markdown]
# 2. Perform Wilcoxon rank sum test using `scipy.stats.ranksums` or `scipy.stats.mannwhitneyu`

# %%
# TODO
