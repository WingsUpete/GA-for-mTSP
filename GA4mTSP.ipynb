# %% [markdown]
# # Genetic Algorithm for Multiple Traveling Salesman Problem

# %% [markdown]
# ## 1. Baseline

# %% [markdown]
# 1. Run baseline on the `mtsp51` instance

# %%
# !python main.py -d instances/mtsp51.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp51.txt
# 	>> 51 cities in total to be loaded
# > 51 cities loaded from instances/mtsp51.txt
# > Initial distance: 1504.379847
# > Starting running GA.
# 	>> cities = 51, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1493.482674
# % 2 1415.022659
# % 3 1343.506094
# % 4 1334.717735
# % 5 1276.647011
# % 6 1258.340652
# % 7 1138.833838
# % 8 1168.934858
# % 9 1159.689399
# % 10 1213.074392
# % 11 1190.657504
# % 12 1180.597209
# % 13 1169.495065
# % 14 1183.981878
# % 15 1131.855049
# % 16 1141.053187
# % 17 1104.442625
# % 18 1148.249560
# % 19 1080.000847
# % 20 1022.202012
# % 21 1034.991293
# % 22 1030.927119
# % 23 1026.250273
# % 24 1026.151463
# % 25 1016.395096
# % 26 996.818111
# % 27 1006.846914
# % 28 971.687255
# % 29 989.380201
# % 30 969.202524
# % 31 1012.978964
# % 32 1039.002877
# % 33 1035.261644
# % 34 1048.301804
# % 35 1025.917716
# ...

# %% [markdown]
# 2. `mtsp100`

# %%
# !python main.py -d instances/mtsp100.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp100.txt
# 	>> 100 cities in total to be loaded
# > 100 cities loaded from instances/mtsp100.txt
# > Initial distance: 151300.221844
# > Starting running GA.
# 	>> cities = 100, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 143415.233637
# % 2 141297.948850
# % 3 139373.608271
# % 4 137354.663812
# % 5 137611.068547
# % 6 135731.358672
# % 7 133322.078729
# % 8 130487.662361
# % 9 128056.534934
# % 10 126194.393207
# % 11 126749.340944
# % 12 126134.685580
# % 13 122668.982859
# % 14 120941.987371
# % 15 121028.912319
# % 16 118087.911107
# % 17 116002.737892
# % 18 116164.939177
# % 19 116447.767310
# % 20 116327.059062
# % 21 112923.456943
# % 22 112366.421242
# % 23 110882.639913
# % 24 108755.309321
# % 25 109988.589025
# % 26 109804.940488
# % 27 106810.769624
# % 28 107554.764686
# % 29 109699.950404
# % 30 107315.926229
# % 31 104372.417213
# ...

# %% [markdown]
# 3. `mtsp150`

# %%
# !python main.py -d instances/mtsp150.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/mtsp150.txt
# 	>> 150 cities in total to be loaded
# > 150 cities loaded from instances/mtsp150.txt
# > Initial distance: 274418.408125
# > Starting running GA.
# 	>> cities = 150, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 271258.978152
# % 2 269764.004968
# % 3 264299.738790
# % 4 262815.993397
# % 5 261570.256862
# % 6 258828.466564
# % 7 252444.845892
# % 8 248005.724312
# % 9 246705.967606
# % 10 238992.348080
# % 11 236149.629381
# % 12 234071.445162
# % 13 231648.118206
# % 14 229493.563394
# % 15 227010.344537
# % 16 225319.928949
# % 17 223522.380479
# % 18 223181.292251
# % 19 219088.610614
# % 20 217985.716506
# % 21 218674.996114
# % 22 215495.415431
# % 23 217334.177544
# % 24 214973.934733
# % 25 214413.307187
# % 26 213803.032970
# % 27 212917.176937
# % 28 213385.242548
# % 29 210067.683165
# % 30 207309.428554
# % 31 205654.058048
# ...

# %% [markdown]
# 4. `pr76`

# %%
# !python main.py -d instances/pr76.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr76.txt
# 	>> 76 cities in total to be loaded
# > 76 cities loaded from instances/pr76.txt
# > Initial distance: 554141.692477
# > Starting running GA.
# 	>> cities = 76, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 526248.586311
# % 2 513855.121002
# % 3 503485.253096
# % 4 480826.692283
# % 5 471944.138189
# % 6 474209.195787
# % 7 463566.642294
# % 8 467985.636009
# % 9 447334.651507
# % 10 450017.052735
# % 11 444343.761316
# % 12 443012.371623
# % 13 439696.137022
# % 14 443294.256139
# % 15 440522.785323
# % 16 434290.406397
# % 17 439550.028974
# % 18 441924.672155
# % 19 431743.664205
# % 20 429567.822056
# % 21 419251.453939
# % 22 429621.153592
# % 23 417280.872320
# % 24 427602.078461
# % 25 415821.480818
# % 26 400860.661515
# % 27 407563.616217
# % 28 407182.451682
# % 29 402649.419241
# % 30 396750.063763
# % 31 396164.898618
# % 32 394747.381812
# ...

# %% [markdown]
# 5. `pr152`

# %%
# !python main.py -d instances/pr152.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr152.txt
# 	>> 152 cities in total to be loaded
# > 152 cities loaded from instances/pr152.txt
# > Initial distance: 1019735.549681
# > Starting running GA.
# 	>> cities = 152, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1006334.198854
# % 2 984184.028238
# % 3 973749.069548
# % 4 938209.740592
# % 5 938344.196521
# % 6 926869.712875
# % 7 925807.113168
# % 8 904704.721885
# % 9 895406.175837
# % 10 889039.902779
# % 11 871722.022726
# % 12 870988.356411
# % 13 875164.701121
# % 14 868209.459536
# % 15 856988.296470
# % 16 863977.362977
# % 17 846380.935639
# % 18 832906.368990
# % 19 827514.474401
# % 20 817810.668586
# % 21 808427.603730
# % 22 794325.594463
# % 23 780481.218427
# % 24 778146.129834
# % 25 759018.750916
# % 26 746371.257214
# % 27 754322.653564
# % 28 744018.353393
# % 29 729986.373404
# % 30 725774.860484
# % 31 719724.259632
# ...

# %% [markdown]
# 6. `pr226`

# %%
# !python main.py -d instances/pr226.txt -ga baseline -so 1 -m 5 -g 1000 -p 100 -dc 20000
# Out:
# --> Running ID = 1
# > Loading cities from instances/pr226.txt
# 	>> 226 cities in total to be loaded
# > 226 cities loaded from instances/pr226.txt
# > Initial distance: 1625125.955967
# > Starting running GA.
# 	>> cities = 226, salesmen = 5
# 	>> Generations = 1000, PopulationSize = 100, TournamentSize = 10
# # Generation Distance
# % 1 1597822.585047
# % 2 1588221.987287
# % 3 1562156.239034
# % 4 1550646.773884
# % 5 1538167.426259
# % 6 1531491.759085
# % 7 1523400.369805
# % 8 1516434.521481
# % 9 1504741.970698
# % 10 1495765.129080
# % 11 1486342.044395
# % 12 1466672.466710
# % 13 1477539.409750
# % 14 1471052.539700
# % 15 1469625.568608
# % 16 1449116.748960
# % 17 1431644.408822
# % 18 1428359.861822
# % 19 1432887.472473
# % 20 1410358.842647
# % 21 1413272.557678
# % 22 1393282.708172
# % 23 1398035.537925
# % 24 1382019.355018
# % 25 1377972.432707
# % 26 1379946.737471
# % 27 1364270.511382
# % 28 1363204.372039
# % 29 1361712.067031
# % 30 1337625.423621
# ...

# %% [markdown]
# ## 2. xxx Algorithm (to compare with baseline)

# %% [markdown]
# 1. Run xxx on the `mtsp51` instance:

# %%
# !python main.py -d instances/mtsp51.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 2. `mtsp100`

# %%
# !python main.py -d instances/mtsp100.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 3. `mtsp150`

# %%
# !python main.py -d instances/mtsp150.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 4. `pr76`

# %%
# !python main.py -d instances/pr76.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 5. `pr152`

# %%
# !python main.py -d instances/pr152.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# 6. `pr226`

# %%
# !python main.py -d instances/pr226.txt -ga myAlgo -so 1 -m 5 -g 1000 -p 100 -dc 20000

# %% [markdown]
# ## 3. Statistical Comparison

# %% [markdown]
# 1. As an example, run baseline multiple indenpendent times on the `mtsp51` instance

# %%
# !python runMultiple.py -d instances/mtsp51.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# Out:
# >>> Total independent runs = 30 <<<
# ------------------------------------------------------------------------------------------------------
# Round 1
# ------------------------------------------------------------------------------------------------------
# Round 2
# ------------------------------------------------------------------------------------------------------
# Round 3
# ------------------------------------------------------------------------------------------------------
# Round 4
# ------------------------------------------------------------------------------------------------------
# Round 5
# ------------------------------------------------------------------------------------------------------
# Round 6
# ------------------------------------------------------------------------------------------------------
# Round 7
# ------------------------------------------------------------------------------------------------------
# Round 8
# ...

# %%
# Run others
# !python runMultiple.py -d instances/mtsp100.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/mtsp150.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/pr76.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/pr152.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30
# !python runMultiple.py -d instances/pr226.txt -ga baseline -so 0 -m 5 -g 1000 -p 100 -dc 20000 -r 30

# %% [markdown]
# 2. Extract result distances from a log folder

# %%
from util import extractFinalDistListFromLogDir

# logDir = 'res/baseline/log/mtsp51_baseline_30_5_1000_100_10_20211216_16_12_09'
# resListBaseline = extractFinalDistListFromLogDir(log_dir=logDir)

# print(resListBaseline)
# Out:
# [935.259838, 931.553625, 936.604977, 916.21368, 911.51114, 921.76074, 913.963646, 908.636433, 922.938775, 946.991411, 917.352276, 898.459824, 883.544144, 908.959496, 913.476104, 937.03381, 951.133978, 879.216739, 914.875664, 933.946606, 909.424986, 927.623173, 912.488888, 917.45265, 898.19543, 932.266037, 934.032096, 911.03959, 913.493121, 911.405061]

# %%
# resListMyAlgo = None

# %% [markdown]
# 3. Perform Wilcoxon rank sum test using `scipy.stats.ranksums` or `scipy.stats.mannwhitneyu` (Testing of difference passes when `p-value` is below 0.05)

# %%
from scipy.stats import ranksums, mannwhitneyu

# print(ranksums(resListBaseline, resListMyAlgo))
# print(mannwhitneyu(resListBaseline, resListMyAlgo))
